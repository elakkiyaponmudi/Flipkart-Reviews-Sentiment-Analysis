# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import emoji

# Load the data
file_path = r"C:\Users\Elakkiya\Downloads\flipkart\oneplus_merged.csv"
df = pd.read_csv(file_path)

# Handle missing values
# Drop rows where the Reviews text is missing
df.dropna(subset=['Review'], inplace=True)

# Ensure all entries in the Reviews column are strings
df['Review'] = df['Review'].astype(str)

# Remove emojis using the emoji library
def remove_emojis(text):
    return emoji.replace_emoji(text, replace='')

# Remove special characters and digits
def remove_special_characters(text):
    return re.sub('[^a-zA-Z\s]', '', text)

# Normalize the text
def normalize_text(text):
    text = text.lower()  # Convert to lowercase
    text = remove_emojis(text)
    text = remove_special_characters(text)
    text = re.sub('\s+', ' ', text)  # Remove extra spaces
    return text

# Apply normalization
df['Cleaned_Review'] = df['Review'].apply(normalize_text)

# Remove stopwords
stop_words = set(stopwords.words('english'))
df['Cleaned_Review'] = df['Cleaned_Review'].apply(lambda x: ' '.join([word for word in x.split() if word not in stop_words]))

# Apply lemmatization
lemmatizer = WordNetLemmatizer()
df['Cleaned_Review'] = df['Cleaned_Review'].apply(lambda x: ' '.join([lemmatizer.lemmatize(word) for word in x.split()]))

# Save the cleaned data to a new CSV file
output_file_path = r"C:\Users\Elakkiya\Downloads\flipkart\oneplus_reviews_cleaned.csv"
df.to_csv(output_file_path, index=False)

print("Data cleaning completed and saved to", output_file_path)
# Out:
# Data cleaning completed and saved to C:\Users\Elakkiya\Downloads\flipkart\oneplus_reviews_cleaned.csv

# %%
import pandas as pd
from autocorrect import Speller

# Load the data
file_path = r"C:\Users\Elakkiya\Downloads\flipkart\oneplus_reviews_cleaned.csv"
df = pd.read_csv(file_path)# Apply autocorrect using autocorrect library
spell = Speller(lang='en')

def correct_spelling(text):
    return ' '.join([spell(word) for word in text.split()])

df['Autocorrected_Review'] = df['Cleaned_Review'].apply(correct_spelling)

# Save the cleaned data to a new CSV file
output_file_path = r"C:\Users\Elakkiya\Downloads\flipkart\oneplus_reviews_autocorrected.csv"
df.to_csv(output_file_path, index=False)

print("Data cleaning and spell correction completed and saved to", output_file_path)
# Out:
# Data cleaning and spell correction completed and saved to C:\Users\Elakkiya\Downloads\flipkart\oneplus_reviews_autocorrected.csv

# %%
import pandas as pd
import re

# Load the cleaned data
file_path = r"C:\Users\Elakkiya\Downloads\flipkart\oneplus_reviews_autocorrected.csv"
df = pd.read_csv(file_path)

# Create a new column 'Reviews' based on 'Autocorrected_Reviews'
df['Reviews'] = df['Autocorrected_Review']

# Dictionary of specific abbreviations and their corrections
abbreviation_dict = {
    'camara': 'camera',
    'fps': 'frames per second',
    'oplus': 'oneplus',
    'sd gen': 'snapdragon generation',
    'superb': 'super',
    'professor': 'processor',
    'sound college': 'sound quality',
    'dam': 'damn',
    'opp': 'oppo',
    'aws': 'awesome',
    'vry gd': 'very good',
    'supppoppp': 'super',
    'prosesar': 'processor',
    'approx hr sot': 'approximately hour screen on time',
    'u': 'you',
    'hr': 'hour',
    'prosper': 'processor',
    'usa': 'usage',
    'good pro': 'good product',
    'gd': 'good',
    'nice prod': 'nice product',
    'p': 'performance',
    'ui': 'user interface',
    'day us': 'day usage',
    'prosesar': 'processor',
    'flipcart': 'flipkart',
    'battery beast': 'battery best',
    'ease': 'easy',
    'pub': 'pubg',
    'osm': 'awesome',
    'worth karma worthuuu': 'worth the money',
    'ois': 'optical image stabilization',
    'aim happy': 'i am happy',
    'pub cod': 'pubg, call of duty',
    'hz': 'hertz',
    'degree census': 'degree celsius',
    'nd': 'and',
    'hit issue': 'heating issue',
    'ai': 'artificial intelligence',
    'wil': 'will',
    'tax': 'thanks',
    'anthem': 'item',
    'mint camera': 'main camera',
    'heat throttle': 'heating and throttling',
    'ill update': 'i will update',
    'phone devils aswoome': 'phone device is awesome',
    'hdr': 'high dynamic range',
    'fo': 'for',
    'op ti really': 'oneplus really',
    'one plus ph': 'oneplus phone',
    'spr': 'super',
    'apprehension': 'appreciation',
    'max': 'maximum',
    'oxygen o': 'oxygen os',
    'kinda': 'kind of',
    'medio': 'mediocre',
    'btw': 'by the way',
    'assam': 'awesome',
    'ph': 'phone',
    'bos': 'range boost',
    'beast': 'best',
    'dlr': 'dslr',
    'batter': 'better',
    'cod': 'call of duty',
    'nyc': 'nice',
    'unvilevebale item': 'unbelievable item',
    'supper': 'super',
    'op': 'oneplus',
    'le':'less',
    'assume': 'awesome',
    'osm dolly atoms': 'awesome dolby atmos',
    'mic failed': 'microphone failed',
    'premium paper': 'premium feel',
    'ver': 'very',
    'gonna': 'going to',
    'pub': 'pubg',
    'gun': 'good',
    'jus': 'just',
    'ive': 'i have',
    'extent': 'excellent',
    'nice hoon': 'nice phone',
    'gr': 'great',
    'math': 'match',
    'bt': 'but',
    'ok':'okay'
}

# Replace abbreviations in the Reviews column
for abbrev, full_form in abbreviation_dict.items():
    # Use word boundaries to ensure only whole words are replaced
    df['Reviews'] = df['Reviews'].str.replace(r'\b' + re.escape(abbrev) + r'\b', full_form, regex=True)

# List of unwanted words
unwanted_words = ['euuuuuuuuuuuuuu', 'imei','xx','o', 'p', 'k', 'x', 'w', 'st', 'isbn', 'gb', 'min', 'mah', 'x x x', 'makhan','bim', 'rd', 'r', 'n', 'nd', 'mm', 'fish', 'apple ka bar', 'mp', 'ppi', 'yrr', 'imei']

# Remove unwanted words from the Reviews column
def remove_unwanted_words(text):
    pattern = r'\b(' + '|'.join(re.escape(word) for word in unwanted_words) + r')\b'
    return re.sub(pattern, '', text)

df['Reviews'] = df['Reviews'].apply(remove_unwanted_words)

# Save the updated DataFrame back to CSV
output_file_path = r"C:\Users\Elakkiya\Downloads\flipkart\oneplus_reviews_final.csv"
df.to_csv(output_file_path, index=False)

print("Corrections made in the Reviews column, and file saved successfully.")
# Out:
# Corrections made in the Reviews column, and file saved successfully.

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import emoji

# Load the data
file_path = r"C:\Users\Elakkiya\Downloads\flipkart\oppo_merged.csv"
df = pd.read_csv(file_path)

# Handle missing values
# Drop rows where the Reviews text is missing
df.dropna(subset=['Review'], inplace=True)

# Ensure all entries in the Reviews column are strings
df['Review'] = df['Review'].astype(str)

# Remove emojis using the emoji library
def remove_emojis(text):
    return emoji.replace_emoji(text, replace='')

# Remove special characters and digits
def remove_special_characters(text):
    return re.sub('[^a-zA-Z\s]', '', text)

# Normalize the text
def normalize_text(text):
    text = text.lower()  # Convert to lowercase
    text = remove_emojis(text)
    text = remove_special_characters(text)
    text = re.sub('\s+', ' ', text)  # Remove extra spaces
    return text

# Apply normalization
df['Cleaned_Review'] = df['Review'].apply(normalize_text)

# Remove stopwords
stop_words = set(stopwords.words('english'))
df['Cleaned_Review'] = df['Cleaned_Review'].apply(lambda x: ' '.join([word for word in x.split() if word not in stop_words]))

# Apply lemmatization
lemmatizer = WordNetLemmatizer()
df['Cleaned_Review'] = df['Cleaned_Review'].apply(lambda x: ' '.join([lemmatizer.lemmatize(word) for word in x.split()]))

# Save the cleaned data to a new CSV file
output_file_path = r"C:\Users\Elakkiya\Downloads\flipkart\oppo_reviews_cleaned.csv"
df.to_csv(output_file_path, index=False)

print("Data cleaning completed and saved to", output_file_path)
# Out:
# Data cleaning completed and saved to C:\Users\Elakkiya\Downloads\flipkart\oppo_reviews_cleaned.csv

# %%
df=pd.read_csv(r"C:\Users\Elakkiya\Downloads\flipkart\oppo_reviews_cleaned.csv")
df.isnull().sum()
# Out:
# Product_Name      0
# Product_Link      0
# Product_Price     0
# Review            0
# Rating            0
# Cleaned_Review    2
# dtype: int64

# %%
# Display the number of missing values in each column
print("Missing values before dropping:\n", df.isnull().sum())

# Drop rows where 'Cleaned_Review' is missing
df.dropna(subset=['Cleaned_Review'], inplace=True)

# Display the number of missing values after dropping
print("Missing values after dropping:\n", df.isnull().sum())
# Out:
# Missing values before dropping:
#  Product_Name      0
# Product_Link      0
# Product_Price     0
# Review            0
# Rating            0
# Cleaned_Review    2
# dtype: int64
# Missing values after dropping:
#  Product_Name      0
# Product_Link      0
# Product_Price     0
# Review            0
# Rating            0
# Cleaned_Review    0
# dtype: int64

# %%
import pandas as pd
from autocorrect import Speller

# Load the data
file_path = r"C:\Users\Elakkiya\Downloads\flipkart\oppo_reviews_cleaned.csv"
df = pd.read_csv(file_path)

# Fill NaN values with an empty string
df['Cleaned_Review'].fillna('', inplace=True)

# Ensure all entries in the Cleaned_Review column are strings
df['Cleaned_Review'] = df['Cleaned_Review'].astype(str)

# Apply autocorrect using autocorrect library
spell = Speller(lang='en')

def correct_spelling(text):
    return ' '.join([spell(word) for word in text.split()])

# Apply spelling correction
df['Autocorrected_Review'] = df['Cleaned_Review'].apply(correct_spelling)

# Save the cleaned data to a new CSV file
output_file_path = r"C:\Users\Elakkiya\Downloads\flipkart\oppo_reviews_autocorrected.csv"
df.to_csv(output_file_path, index=False)

print("Data cleaning and spell correction completed and saved to", output_file_path)
# Out:
# Data cleaning and spell correction completed and saved to C:\Users\Elakkiya\Downloads\flipkart\oppo_reviews_autocorrected.csv

# %%
import pandas as pd
import re

# Load the cleaned data
file_path = r"C:\Users\Elakkiya\Downloads\flipkart\oppo_reviews_autocorrected.csv" 
df = pd.read_csv(file_path)

# Create a new column 'Reviews' based on 'Autocorrected_Reviews'
df['Reviews'] = df['Autocorrected_Review']

# Dictionary of specific abbreviations and their corrections
abbreviation_dict = {
    'camara': 'camera','fps': 'frames per second','oplus': 'oneplus','sd gen': 'snapdragon generation', 'superb': 'super',
    'professor': 'processor','sound college': 'sound quality','dam': 'damn','opp': 'oppo','aws': 'awesome',
    'vry gd': 'very good','supppoppp': 'super','prosesar': 'processor','approx hr sot': 'approximately hour screen on time',
    'u': 'you','hr': 'hour','prosper': 'processor','usa': 'usage','good pro': 'good product','gd': 'good',
    'nice prod': 'nice product','p': 'performance','ui': 'user interface','day us': 'day usage','prosesar': 'processor',
    'flipcart': 'flipkart','battery beast': 'battery best','ease': 'easy','pub': 'pubg','osm': 'awesome',
    'worth karma worthuuu': 'worth the money','ois': 'optical image stabilization','aim happy': 'i am happy',
    'pub cod': 'pubg, call of duty','hz': 'hertz','degree census': 'degree celsius','nd': 'and',
    'hit issue': 'heating issue','ai': 'artificial intelligence','wil': 'will','tax': 'thanks', 'anthem': 'item',
    'mint camera': 'main camera','heat throttle': 'heating and throttling','ill update': 'i will update',
    'phone devils aswoome': 'phone device is awesome','hdr': 'high dynamic range','fo': 'for',
    'op ti really': 'oneplus really','one plus ph': 'oneplus phone','spr': 'super','apprehension': 'appreciation',
    'max': 'maximum','oxygen o': 'oxygen os','kinda': 'kind of','medio': 'mediocre','btw': 'by the way','assam': 'awesome',
    'ph': 'phone','bos': 'range boost','beast': 'best','dlr': 'dslr','batter': 'better','cod': 'call of duty','nyc': 'nice',
    'unvilevebale item': 'unbelievable item','supper': 'super','op': 'oneplus','assume': 'awesome',
    'osm dolly atoms': 'awesome dolby atmos','mic failed': 'microphone failed','premium paper': 'premium feel','ver': 'very',
    'gonna': 'going to', 'pub': 'pubg', 'gun': 'good','jus': 'just','ive': 'i have','extent': 'excellent','nice hoon': 'nice phone',
    'gr': 'great','math': 'match','bt': 'but','ok':'okay', 'costa': 'costar', 'beast': 'best', 'hr': 'hour','sha': 'should',
    'wk': 'week', "hadnt": "had not","im": "i am","havent": "have not", "hasnt": "has not", 'u': "you", 'r': "are",
    "ui": "user interface", "doesnt": "does not", 'rambling': "rumbling", "io": "iphone operating system", 
    "sot": "special operation team", "le": "less", "fhd": "full high definition", "dont": "do not",
    "cam": "camera", "came": "camera", "avg": "average","yea": "yeah", "lil": "little", 
    "costlier": "more expensive", "it's": "it is", "very": "very", "n": "and", "cant": "cannot", "dis": "this", "v": "we", 
    "hdr": 'high dynamic range', "didnt": "did not", "ive": "i have", "bezel": "bezel", "ur": "your", "wont": 'will not', 
    "hd": 'high definition', 'cleanui': "clean user interface", "tatics": "haptics", "sd": "secure digital", "gen": "generation", 
    "usp": 'unique selling proposition', 'degc': "degree celsius", "tatic": "haptic", "unbuilt": "inbuilt", 'xiomi': "xiaomi",
    'regreating': "regretting", 'fyi': "for your information", 'issuehrs': "issue hours", 'doomed': "zoomed",
    'ois': "optical image stabilization", 'theyll': "they will", 'ig': "instagram", 'bbd': "bigger better deal", 'cemra': "camera", 
    'fastly': "fast", "optimise": 'optimize', 'osum': 'awesome', 'vi': "vodafone", 'upi': "unified payments interface",
    'eyeturner': "eye turner", 'banger': "banger", 're': "resolution", 'goddamn': "goddamn", 'aint': "am not", 'plesently': "pleasantly", 
    'thik': "think", "tooo": "too", "uisvery": 'user interface very', 'gif': "graphics interchange format", 'siz': "six", 
    'costlier': "costlier", 'iphones': "iphone", 'youre': 'you are', 'doubtbut': "doubt but", 'phome': "phone", 'red': "redmi", 
    'okif': "okay if", 'pic': "picture", 'smatter': 'smarter', 'membrane': "ambrane", "holdnew": 'hold new', 'swine': "swipe", 
    'inshot': "inshot", 'pixelated': "pixel related", 'cameraai': "camera artificial intelligence", 'oppos': 'oppo', 'amaze': "amazing", 
    'daytoday': "day to day", 'offmy': "off my", 'laggy': "lag", 'victus': "victus", 'slowlike': "slow like",
    'wholeday': "full day",'commendable': "recommendable",'baku': "vaku", 
    'beat': "best", 'surfed': "suffered", 'bgmi': "battle ground mobile india",'isnt': "is not", 
    'flickering': "flickering", 'least': "at least", 'doun': "down", 'thats': "that is", 'ill': "i will", 'bout': "about", 
    'butter': "better", 'emi': "equated monthly installment", 'prefect': "perfect", 'ketone': "keyone", 
    'ie': "in other words", 'cuz': "because","youve": "you have",'ott': "over the top", 
    'oct': "october", 'ois': "optical image stabilization", 'ip': "iphone", 'nowhope': "now hope", 'red': "redmi",
    "eraserunblur": "eraser focus", "wifi": "wireless fidelity", 'ok': "okay", 'hiccup': "hiccup",
    'janso': "january so", 'mahmaybe': "milliampere hour may be", 'lovable': "lovable", 'etc': "et cetera","karma": "varma",
    'dayyyyyyyy': "day", 'pic': "picture", 'camra': "camera", 'Vry': "very", 'easilllyy': "easily",
    'came': "camera", 'mob': "mobile", 'flipcard': "flipkart", 'Kkk': "okay",'swimmer':'shimmery'
    # Add more abbreviations and corrections as needed
}

# Replace abbreviations in the Reviews column
for abbrev, full_form in abbreviation_dict.items():
    # Use word boundaries to ensure whole words are replaced
    df['Reviews'] = df['Reviews'].str.replace(r'\b' + abbrev + r'\b', full_form, case=False, regex=True)

# Unwanted words to remove
unwanted_words = ['euuuuuuuuuuuuuu', 'imei','xx','o', 'p', 'k', 'x', 'w', 'st', 'isbn', 'gb', 'min', 'mah', 'x x x', 'makhan','bim', 'rd', 'r',
                  'n', 'nd', 'mm', 'fish', 'apple ka bar', 'mp', 'ppi', 'yrr', 'imei','k', 'science', 'x', 'nd', 'rd', 'le', 'st', 'p', 'pm', 'f',
                  'tho', 'h', 'th', 'gn', 'xr', 'xl', 'am', 'tg', 'p', 'z','ce', 'ip', 'lt', 'td', 'gt', 'lea', 'la', 'der', 'ir', 'j',
                  'sp', 'th', 'v', 'cg', 'wee', 'seg','g','pro'
]

# Remove unwanted words
for word in unwanted_words:
    df['Reviews'] = df['Reviews'].str.replace(r'\b' + word + r'\b', '', case=False, regex=True)

# Save the updated DataFrame to a new CSV file
output_file_path = r"C:\Users\Elakkiya\Downloads\flipkart\oppo_reviews_final.csv"
df.to_csv(output_file_path, index=False)

print("Data cleaned and saved successfully.")
# Out:
# Data cleaned and saved successfully.

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import emoji

# Load the data
file_path = r"C:\Users\Elakkiya\Downloads\flipkart\Honor_merged.csv"
df = pd.read_csv(file_path)

# Handle missing values
# Drop rows where the Reviews text is missing
df.dropna(subset=['Review'], inplace=True)

# Ensure all entries in the Reviews column are strings
df['Review'] = df['Review'].astype(str)

# Remove emojis using the emoji library
def remove_emojis(text):
    return emoji.replace_emoji(text, replace='')

# Remove special characters and digits
def remove_special_characters(text):
    return re.sub('[^a-zA-Z\s]', '', text)

# Normalize the text
def normalize_text(text):
    text = text.lower()  # Convert to lowercase
    text = remove_emojis(text)
    text = remove_special_characters(text)
    text = re.sub('\s+', ' ', text)  # Remove extra spaces
    return text

# Apply normalization
df['Cleaned_Review'] = df['Review'].apply(normalize_text)

# Remove stopwords
stop_words = set(stopwords.words('english'))
df['Cleaned_Review'] = df['Cleaned_Review'].apply(lambda x: ' '.join([word for word in x.split() if word not in stop_words]))

# Apply lemmatization
lemmatizer = WordNetLemmatizer()
df['Cleaned_Review'] = df['Cleaned_Review'].apply(lambda x: ' '.join([lemmatizer.lemmatize(word) for word in x.split()]))

# Save the cleaned data to a new CSV file
output_file_path = r"C:\Users\Elakkiya\Downloads\flipkart\Honor_reviews_cleaned.csv"
df.to_csv(output_file_path, index=False)

print("Data cleaning completed and saved to", output_file_path)
# Out:
# Data cleaning completed and saved to C:\Users\Elakkiya\Downloads\flipkart\Honor_reviews_cleaned.csv

# %%
import pandas as pd
from autocorrect import Speller

# Load the data
file_path = r"C:\Users\Elakkiya\Downloads\flipkart\Honor_reviews_cleaned.csv"
df = pd.read_csv(file_path)

# Fill NaN values with an empty string
df['Cleaned_Review'].fillna('', inplace=True)

# Ensure all entries in the Cleaned_Review column are strings
df['Cleaned_Review'] = df['Cleaned_Review'].astype(str)

# Apply autocorrect using autocorrect library
spell = Speller(lang='en')

def correct_spelling(text):
    return ' '.join([spell(word) for word in text.split()])

# Apply spelling correction
df['Autocorrected_Review'] = df['Cleaned_Review'].apply(correct_spelling)

# Save the cleaned data to a new CSV file
output_file_path = r"C:\Users\Elakkiya\Downloads\flipkart\Honor_reviews_autocorrected.csv"
df.to_csv(output_file_path, index=False)

print("Data cleaning and spell correction completed and saved to", output_file_path)
# Out:
# Data cleaning and spell correction completed and saved to C:\Users\Elakkiya\Downloads\flipkart\Honor_reviews_autocorrected.csv

# %%
import pandas as pd
import re

# Load the cleaned data
file_path = r"C:\Users\Elakkiya\Downloads\flipkart\Honor_reviews_autocorrected.csv"
df = pd.read_csv(file_path)

# Create a new column 'Reviews' based on 'Autocorrected_Reviews'
df['Reviews'] = df['Autocorrected_Review']

# Dictionary of specific abbreviations and their corrections
abbreviation_dict = {
    'camara': 'camera', 'fps': 'frames per second', 'oplus': 'oneplus', 'sd gen': 'snapdragon generation', 'superb': 'super',
    'professor': 'processor', 'sound college': 'sound quality', 'dam': 'damn', 'opp': 'oppo', 'aws': 'awesome',
    'vry gd': 'very good', 'supppoppp': 'super', 'prosesar': 'processor', 'approx hr sot': 'approximately hour screen on time',
    'u': 'you', 'hr': 'hour', 'prosper': 'processor', 'usa': 'usage', 'good pro': 'good product', 'gd': 'good',
    'nice prod': 'nice product', 'p': 'performance', 'ui': 'user interface', 'day us': 'day usage', 'prosesar': 'processor',
    'flipcart': 'flipkart', 'battery beast': 'battery best', 'ease': 'easy', 'pub': 'pubg', 'osm': 'awesome',
    'worth karma worthuuu': 'worth the money', 'ois': 'optical image stabilization', 'aim happy': 'i am happy',
    'pub cod': 'pubg, call of duty', 'hz': 'hertz', 'degree census': 'degree celsius', 'nd': 'and',
    'hit issue': 'heating issue', 'ai': 'artificial intelligence', 'wil': 'will', 'tax': 'thanks', 'anthem': 'item',
    'mint camera': 'main camera', 'heat throttle': 'heating and throttling', 'ill update': 'i will update',
    'phone devils aswoome': 'phone device is awesome', 'hdr': 'high dynamic range', 'fo': 'for',
    'op ti really': 'oneplus really', 'one plus ph': 'oneplus phone', 'spr': 'super', 'apprehension': 'appreciation',
    'max': 'maximum', 'oxygen o': 'oxygen os', 'kinda': 'kind of', 'medio': 'mediocre', 'btw': 'by the way', 'assam': 'awesome',
    'ph': 'phone', 'bos': 'range boost', 'beast': 'best', 'dlr': 'dslr', 'batter': 'better', 'cod': 'call of duty', 'nyc': 'nice',
    'unvilevebale item': 'unbelievable item', 'supper': 'super', 'op': 'oneplus', 'assume': 'awesome',
    'osm dolly atoms': 'awesome dolby atmos', 'mic failed': 'microphone failed', 'premium paper': 'premium feel', 'ver': 'very',
    'gonna': 'going to', 'pub': 'pubg', 'gun': 'good', 'jus': 'just', 'ive': 'i have', 'extent': 'excellent', 'nice hoon': 'nice phone',
    'gr': 'great', 'math': 'match', 'bt': 'but', 'ok':'okay', 'costa': 'costar', 'beast': 'best', 'hr': 'hour', 'sha': 'should',
    'wk': 'week', "hadnt": "had not", "im": "i am", "havent": "have not", "hasnt": "has not", 'u': "you", 'r': "are",
    "ui": "user interface", "doesnt": "does not", 'rambling': "rumbling", "io": "iphone operating system", 
    "sot": "special operation team", "le": "less", "fhd": "full high definition", "dont": "do not",
    "cam": "camera", "came": "camera", "avg": "average", "yea": "yeah", "lil": "little", 
    "costlier": "more expensive", "it's": "it is", "very": "very", "n": "and", "cant": "cannot", "dis": "this", "v": "we", 
    "hdr": 'high dynamic range', "didnt": "did not", "ive": "i have", "bezel": "bezel", "ur": "your", "wont": 'will not', 
    "hd": 'high definition', 'cleanui': "clean user interface", "tatics": "haptics", "sd": "secure digital", "gen": "generation", 
    "usp": 'unique selling proposition', 'degc': "degree celsius", "tatic": "haptic", "unbuilt": "inbuilt", 'xiomi': "xiaomi",
    'regreating': "regretting", 'fyi': "for your information", 'issuehrs': "issue hours", 'doomed': "zoomed",
    'ois': "optical image stabilization", 'theyll': "they will", 'ig': "instagram", 'bbd': "bigger better deal", 'cemra': "camera", 
    'fastly': "fast", "optimise": 'optimize', 'osum': 'awesome', 'vi': "vodafone", 'upi': "unified payments interface",
    'eyeturner': "eye turner", 'banger': "banger", 're': "resolution", 'goddamn': "goddamn", 'aint': "am not", 'plesently': "pleasantly", 
    'thik': "think", "tooo": "too", "uisvery": 'user interface very', 'gif': "graphics interchange format", 'siz': "six", 
    'costlier': "costlier", 'iphones': "iphone", 'youre': 'you are', 'doubtbut': "doubt but", 'phome': "phone", 'red': "redmi", 
    'okif': "okay if", 'pic': "picture", 'smatter': 'smarter', 'membrane': "ambrane", "holdnew": 'hold new', 'swine': "swipe", 
    'inshot': "inshot", 'pixelated': "pixel related", 'cameraai': "camera artificial intelligence", 'oppos': 'oppo', 'amaze': "amazing", 
    'daytoday': "day to day", 'offmy': "off my", 'laggy': "lag", 'victus': "victus", 'slowlike': "slow like",
    'wholeday': "full day", 'commendable': "recommendable", 'baku': "vaku", 
    'beat': "best", 'surfed': "suffered", 'bgmi': "battle ground mobile india", 'isnt': "is not", 
    'flickering': "flickering", 'least': "at least", 'doun': "down", 'thats': "that is", 'ill': "i will", 'bout': "about", 
    'butter': "better", 'emi': "equated monthly installment", 'prefect': "perfect", 'ketone': "keyone", 
    'ie': "in other words", 'cuz': "because", "youve": "you have", 'ott': "over the top", 
    'oct': "october", 'ois': "optical image stabilization", 'ip': "iphone", 'nowhope': "now hope", 'red': "redmi",
    "eraserunblur": "eraser focus", "wifi": "wireless fidelity", 'ok': "okay", 'hiccup': "hiccup",
    'janso': "january so", 'mahmaybe': "milliampere hour may be", 'lovable': "lovable", 'etc': "et cetera", "karma": "varma",
    'dayyyyyyyy': "day", 'pic': "picture", 'camra': "camera", 'Vry': "very", 'easilllyy': "easily",
    'came': "camera", 'mob': "mobile", 'flipcard': "flipkart", 'Kkk': "okay", 'swimmer': 'shimmery', 'supeeeeer': 'super', 'ur': 'your', 'nais': 'nice', 'descent': 'decent', 'se user': 'super', 'nris': 'nice',
    'suuuuuuuuuuuuuuper': 'super', 'project': 'product', 'xtra': 'extra', 'userniterface': 'user interface', 'prossecer': 'processor', 'amazingest': 'amazing',
    'col': 'color', 'superbbbbb': 'superb', 'goog': 'good', 'censor': 'sensor', 'ram': 'ram', 'wwwhhhoooooooo': 'who', 'pictre': 'picture', 'comera': 'camera', 'fa': 'for',
    'truely': 'truly', 'fonnne': 'phone', 'excellant': 'excellent', 'totallly': 'totally', 'ceramicback': 'ceramic back', 'internat': 'internet', 'iui': 'miui', 'camaera': 'camera', 'supper': 'super',
    'exllent': 'excellent', 'magnafiqui': 'magnificent', 'affecfordble': 'affordable', 'smmmmooooothhhhhh': 'smooth', 'veryg': 'very good', 'camaera': 'camera',
    'ar': 'are', 'eet': 'get', 'june': 'june', 'ster': 'star', 'osam': 'awesome', 'gona': 'gonna', 'suchh': 'such', 'amoled': 'amoled', 'fon': 'phone', 'ram': 'ram', 'exp': 'expensive',
    'xclent': 'excellent', 'ans': 'and', 'shotcut': 'shortcut', 'expoerience': 'experience', 'bgmi': 'battle grounds mobile india', 'anr': 'and', 'whao': 'wow', 'awesomeeee': 'awesome', 'blurr': 'blur',
    'definately': 'definitely', 'suuuuper': 'super', 'nize': 'nice', 'phobe': 'phone', 'thanksflipcart': 'thanks flipkart', 'mimax': 'mi max', 'picure': 'picture', 'blutooth': 'bluetooth', 'qhy': 'why',
    'user interfce': 'user interface', 'beasutiful': 'beautiful', 'smother': 'smoother', 'gooddd': 'good', 'ramgood': 'ram good', 'smother': 'smoother', 'suggestable': 'suggestible', 'gamesro': 'games to',
    'playbles': 'playable', 'fes': 'fest', 'crystalclear': 'crystal clear', 'ph': 'phone', 'frimeware': 'firmware', 'dowload': 'download', 'camara': 'camera', 'gud': 'good', 'jio': 'jio', 'againflipkart': 'again flipkart',
    'imposible': 'impossible', 'comfortbale': 'comfortable', 'whith': 'with', 'chages': 'changes', 'consiser': 'consider', 'heatsup': 'heats up', 'grt': 'great', 'fringerprint': 'fingerprint', 'detailingg': 'detailing',
    'gud': 'good', 'hz': 'hertz', 'nd': 'and', 'soundcollage': 'sound quality', 'wi': 'with', 'appreciateble': 'appreciable', 'phn': 'phone', 'mu': 'music', 'preforance': 'performance', 'veryyy': 'very',
    'ceramicback': 'ceramic back', 'ceraicback': 'ceramic back', 'battrey': 'battery', 'hollywow': 'hollywood', 'expirence': 'experience', 'niceui': 'nice user interface', 'terriffic': 'terrific', 'varien': 'variant',
    'xcellent': 'excellent', 'sorring': 'scoring', 'comfrtable': 'comfortable', 'mics': 'microphones', 'cds': 'cd', 'whot': 'what', 'mindbloing': 'mind blowing', 'gamesome': 'games on', 'fluently': 'fluent',
    'dat': 'that', 'amasing': 'amazing', 'superrr': 'super', 'osm': 'awesome', 'hreat': 'great', 'costefficeint': 'cost efficient', 'bhaskar': 'bhaskaran', 'heatingproblem': 'heating problem',
    'miracast': 'miracast', 'definately': 'definitely', 'wo': 'would', 'thsnks': 'thanks', 'whywhy': 'why why', 'cam': 'camera', 'gaurantee': 'guarantee', 'crazychaging': 'crazy charging',
    'interfece': 'interface', 'excellant': 'excellent', 'intenation': 'internet', 'bettry': 'battery', 'exellent': 'excellent', 'lockscreen': 'lock screen', 'tap': 'tap', 'eb': 'is',
    'cam': 'camera', 'exellent': 'excellent', 'pros': 'pros', 'cus': 'because', 'definatly': 'definitely', 'microphoneon': 'microphone on', 'renaining': 'remaining', 'nxet': 'next',
    'switcher': 'switcher', 'yooo': 'yo', 'exlent': 'excellent', 'vol': 'volume', 'magic': 'magic', 'beacuse': 'because', 'ven': 'even', 'expence': 'expense', 'pones': 'phones',
    'pu': 'pubg', 'exlent': 'excellent', 'bgmi': 'battle ground mobile india', 'athir': 'arshad', 'ramaining': 'remaining', 'docing': 'docking', 'batterylife': 'battery life', 'batt': 'battery', 
    'cas': 'case', 'proble': 'problem', 'sa': 'sa', 'lense': 'lens', 'cameraof': 'camera of', 'parformance': 'performance', 'whatsapp': 'whatsapp', 'camra': 'camera', 'amoleddisplay': 'amoled display',
    'hugh': 'high', 'exellent': 'excellent', 'phon': 'phone', 'boaring': 'boring', 'sync': 'sync', 'flipkart': 'flipkart', 'tp': 'to', 'displayflipkart': 'display flipkart', 'flipcart': 'flipkart',
    'complain': 'complain', 'sdgen': 'snapdragon generation', 'comerabgmi': 'camera battle ground mobile india', 'doint': 'do not', 'iys': 'it is', 'superp': 'super', 'expeeience': 'experience', 'loook': 'look',
    'couple': 'couple', 'phoneflipkart': 'phone flipkart', 'got': 'got', 'consisency': 'consistency', 'dispkay': 'display', 'proc': 'processor', 'gud': 'good', 'clarityclearity': 'clarity', 'octo': 'octa',
    'excessive': 'excessive', 'goodem': 'good em', 'snapdragon': 'snapdragon', 'camara': 'camera', 'sper': 'super', 'rebooting': 'rebooting', 'accessorry': 'accessory', 'usr': 'user', 'dispkay': 'display',
    'pictureclarity': 'picture clarity', 'dispkayclarity': 'display clarity', 'extremely': 'extremely', 'awsome': 'awesome', 'goodcamera': 'good camera', 'goodclatrity': 'good clarity', 'miui': 'miui',
    'clearn': 'clear', 'cllick': 'click', 'reseting': 'resetting', 'psl': 'psl', 'edxtra': 'extra', 'redmy': 'redmi', 'gamy': 'game', 'biometrics': 'biometrics', 'noney': 'money', 'lenovo': 'lenovo',
    'possessing': 'processing', 'ossam': 'awesome', 'tis': 'this', 'surport': 'support', 'awsom': 'awesome', 'supere': 'super', 'serviceflipkart': 'service flipkart', 'awesomeas': 'awesome', 'greate': 'great',
    'mobs': 'mobile', 'sept': 'september', 'its': 'its', 'wasawsm': 'was awesome', 'flipkartgood': 'flipkart good', 'easeofuse': 'ease of use', 'mi': 'mi', 'perfectperfect': 'perfect', 'ohow': 'oh how',
    'dosn': 'does', 'okkay': 'okay', 'awdome': 'awesome', 'des': 'des', 'awesomefeature': 'awesome feature', 'circa': 'circa', 'gud': 'good', 'backca': 'back cover', 'yhe': 'the', 'niceproduct': 'nice product',
    'me':'mi', 'awesomegod': 'awesome', 'tricking': 'tricking', 'allure': 'allure', 'mia1': 'mi a1', 'backpanel': 'back panel', 'microwave': 'microphone', 'fri': 'friend', 'frusterating': 'frustrating',
    'rs': 'rs', 'chat': 'chat', 'saiz': 'size', 'ram': 'ram', 'workswll': 'works well', 'mid': 'mi', 'ph': 'phone', 'flpkrt': 'flipkart', 'blowming': 'blowing', 'complaince': 'complain', 'ar': 'are', 'phn': 'phone',
    'usb': 'usb', 'coverback': 'cover back', 'awesomecamera': 'awesome camera', 'osame': 'awesome', 'bat': 'battery', 'weighing': 'weighing', 'midrange': 'mid range', 'blowng': 'blowing', 'yoursite': 'your site',
    'superbg': 'superb', 'intetnet': 'internet', 'besutiful': 'beautiful', 'suuuper': 'super', 'ate': 'ate', 'ceramicback': 'ceramic back', 'velvet': 'velvet', 'goog': 'good', 'doeswork': 'does work', 'interrface': 'interface',
    'spellings': 'spellings', 'competetion': 'competition', 'clarityis': 'clarity is', 'xclent': 'excellent', 'crome': 'chrome', 'sinply': 'simply', 'cermaic': 'ceramic', 'plz': 'please', 'compability': 'compatibility',
    'excellnt': 'excellent', 'iui': 'miui', 'ultraa': 'ultra', 'whatsoever': 'whatsoever', 'goodand': 'good and', 'gotcamera': 'got camera', 'ple': 'please', 'afortable': 'affordable', 'kns': 'kms', 'nicefeature': 'nice feature',
    'redemi': 'redmi', 'xxent': 'excellent', 'cuttrt': 'cutout', 'mi': 'mi', 'serires': 'series', 'whish': 'wish', 'dlexo': 'deluxe', 'cristal': 'crystal', 'makesense': 'make sense', 'gud': 'good', 'expellience': 'experience',
    'reflectiion': 'reflection', 'microphone': 'microphone', 'cameraquality': 'camera quality', 'awesomef': 'awesome', 'guddisplay': 'good display', 'frustrting': 'frustrating', 'vol': 'volume', 'cermaic': 'ceramic', 'clearence': 'clearance', 
    'snapdragon': 'snapdragon', 'ceramicback': 'ceramic back', 'cermaicback': 'ceramic back', 'snapdragon820': 'snapdragon 820', 'miui8': 'miui 8', 'snapdragon': 'snapdragon', 'snapdragon': 'snapdragon', 'snapdragon835': 'snapdragon 835', 'snapdragon820': 'snapdragon 820'
}
# Replace abbreviations in the Reviews column
for abbrev, full_form in abbreviation_dict.items():
    # Use word boundaries to ensure whole words are replaced
    df['Reviews'] = df['Reviews'].str.replace(r'\b' + abbrev + r'\b', full_form, case=False, regex=True)

unwanted_words = [
    'euuuuuuuuuuuuuu', 'imei', 'xx', 'o', 'p', 'k', 'x', 'w', 'st', 'isbn', 'gb', 'min', 'mah', 'x x x', 'makhan',
    'bim', 'rd', 'r', 'n', 'nd', 'mm', 'fish', 'apple ka bar', 'mp', 'ppi', 'yrr', 'imei', 'k', 'science', 'x', 'nd',
    'rd', 'le', 'st', 'p', 'pm', 'f', 'tho', 'h', 'th', 'gn', 'xr', 'xl', 'am', 'tg', 'p', 'z', 'ce', 'ip', 'lt', 'td',
    'gt', 'lea', 'la', 'der', 'ir', 'j', 'sp', 'th', 'v', 'cg', 'wee', 'seg', 'g', 'pro', 'x', 'p', 'e', 'opt', 'nfc',
    'tm', 'ir', 'xnd', 'ffd', 'htc', 'cal', 'pm', 'ordo', 'gh', 'rn', 'mia', 'ip', 'sd', 'oct', 'core', 'expos', 'rd',
    'ip', 'pe', 'amp', 'paisa bassol', 'pc', 'al', 'zindabad', 'dnd', 'rsk', 'g', 'ooooooo', 'mmmmmmm', 'ggggggg', 'vfd',
    'havoc', 'ah', 'hi', 'hai', 'swimming', 'gop', 'ji', 'lajawab', 'asap loose', 'ie', 'h ago', 'madathukulam', 'mo', 
    'fea', 'l', 'ex', 'qu', 'Lotus', 'voodoo', 'ko', 'ont', 'maa', 'ag', 'ne', 'quot', 'sakuntala', 'rayagada bissamcuttack',
    'gimmick', 'thi', 'str', 'fatafati', 'mast', 'garcia jharkhand', 'sa', 'isvudn', 'x', 'sg', 'hijab', 'tbh', 'wars', 
    'nts', 'huawei', 'keirin', 'ofc', 'pg', 'sec', 'jaar', 'hai ye', 'th', 'ft', 'emu', 'gpu', 'fr', 'nit', 'eis', 'oo',
    'hh', 'ly', 'fei', 'q', 'c', 'sw', 'kd', 'ofc', 'bl', 'lol', 'et', 'rgh', 'extremewwe', 'dts', 'iu', 'vr', 'Soo', 
    'al', 'sm', 'rsk', 'eta', 'gh', 'nu', 'ota', 'fp'
]
# Remove unwanted words
for word in unwanted_words:
    df['Reviews'] = df['Reviews'].str.replace(r'\b' + word + r'\b', '', case=False, regex=True)

# Save the updated DataFrame to a new CSV file
output_file_path = r"C:\Users\Elakkiya\Downloads\flipkart\Honor_reviews_final.csv"
df.to_csv(output_file_path, index=False)

print("Data cleaned and saved successfully.")
# Out:
# Data cleaned and saved successfully.

# %%
'supeeeeer':'super','ur':'your','nais':'nice','descent':'decent','se user':'super','nris':'nice',
'suuuuuuuuuuuuuuper':'super','project':'product','xtra':'extra','userniterface':'user interface','prossecer':'processor''amazingest':'amazing',
'col':'because','youre':'your','nov':'november','http':'hitup','hitting':'heating','sam':'awesome','nic':'nice','allk' : 'all'

x,sg,hijab,tbh,wars,nts,huawei,keirin,ofc,pg,sec,jaar,hai ye,th,ft,emu,gpu,fr,nit,'eis', 'oo', 'hh, ly, fei, q, c, sw, kd, ofc,bl, lol,et, rgh,
extremewwe: extreme, dts, iu, vr,Soo: so, 
al, sm, rsk, eta, gh, nu, ota,fp

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import emoji

# Load the data
file_path = r"C:\Users\Elakkiya\Downloads\flipkart\motorola_merged.csv"
df = pd.read_csv(file_path)

# Handle missing values
# Drop rows where the Reviews text is missing
df.dropna(subset=['Review'], inplace=True)

# Ensure all entries in the Reviews column are strings
df['Review'] = df['Review'].astype(str)

# Remove emojis using the emoji library
def remove_emojis(text):
    return emoji.replace_emoji(text, replace='')

# Remove special characters and digits
def remove_special_characters(text):
    return re.sub('[^a-zA-Z\s]', '', text)

# Normalize the text
def normalize_text(text):
    text = text.lower()  # Convert to lowercase
    text = remove_emojis(text)
    text = remove_special_characters(text)
    text = re.sub('\s+', ' ', text)  # Remove extra spaces
    return text

# Apply normalization
df['Cleaned_Review'] = df['Review'].apply(normalize_text)

# Remove stopwords
stop_words = set(stopwords.words('english'))
df['Cleaned_Review'] = df['Cleaned_Review'].apply(lambda x: ' '.join([word for word in x.split() if word not in stop_words]))

# Apply lemmatization
lemmatizer = WordNetLemmatizer()
df['Cleaned_Review'] = df['Cleaned_Review'].apply(lambda x: ' '.join([lemmatizer.lemmatize(word) for word in x.split()]))

# Save the cleaned data to a new CSV file
output_file_path = r"C:\Users\Elakkiya\Downloads\flipkart\motorola_reviews_cleaned.csv"
df.to_csv(output_file_path, index=False)

print("Data cleaning completed and saved to", output_file_path)
# Out:
# Data cleaning completed and saved to C:\Users\Elakkiya\Downloads\flipkart\motorola_reviews_cleaned.csv

# %%
import pandas as pd
from autocorrect import Speller

# Load the data
file_path = r"C:\Users\Elakkiya\Downloads\flipkart\motorola_reviews_cleaned.csv"
df = pd.read_csv(file_path)

# Fill NaN values with an empty string
df['Cleaned_Review'].fillna('', inplace=True)

# Ensure all entries in the Cleaned_Review column are strings
df['Cleaned_Review'] = df['Cleaned_Review'].astype(str)

# Apply autocorrect using autocorrect library
spell = Speller(lang='en')

def correct_spelling(text):
    return ' '.join([spell(word) for word in text.split()])

# Apply spelling correction
df['Autocorrected_Review'] = df['Cleaned_Review'].apply(correct_spelling)

# Save the cleaned data to a new CSV file
output_file_path = r"C:\Users\Elakkiya\Downloads\flipkart\motorola_reviews_autocorrected.csv"
df.to_csv(output_file_path, index=False)

print("Data cleaning and spell correction completed and saved to", output_file_path)
# Out:
# Data cleaning and spell correction completed and saved to C:\Users\Elakkiya\Downloads\flipkart\motorola_reviews_autocorrected.csv

# %%
import pandas as pd
import re

# Load the cleaned data
file_path = r"C:\Users\Elakkiya\Downloads\flipkart\motorola_reviews_autocorrected.csv"
df = pd.read_csv(file_path)

# Create a new column 'Reviews' based on 'Autocorrected_Reviews'
df['Reviews'] = df['Autocorrected_Review']

# Dictionary of specific abbreviations and their corrections
abbreviation_dict = {
    'camara': 'camera', 'fps': 'frames per second', 'oplus': 'oneplus', 'sd gen': 'snapdragon generation', 'superb': 'super',
    'professor': 'processor', 'sound college': 'sound quality', 'dam': 'damn', 'opp': 'oppo', 'aws': 'awesome',
    'vry gd': 'very good', 'supppoppp': 'super', 'prosesar': 'processor', 'approx hr sot': 'approximately hour screen on time',
    'u': 'you', 'hr': 'hour', 'prosper': 'processor', 'usa': 'usage', 'good pro': 'good product', 'gd': 'good',
    'nice prod': 'nice product', 'p': 'performance', 'ui': 'user interface', 'day us': 'day usage', 'prosesar': 'processor',
    'flipcart': 'flipkart', 'battery beast': 'battery best', 'ease': 'easy', 'pub': 'pubg', 'osm': 'awesome',
    'worth karma worthuuu': 'worth the money', 'ois': 'optical image stabilization', 'aim happy': 'i am happy',
    'pub cod': 'pubg, call of duty', 'hz': 'hertz', 'degree census': 'degree celsius', 'nd': 'and',
    'hit issue': 'heating issue', 'ai': 'artificial intelligence', 'wil': 'will', 'tax': 'thanks', 'anthem': 'item',
    'mint camera': 'main camera', 'heat throttle': 'heating and throttling', 'ill update': 'i will update',
    'phone devils aswoome': 'phone device is awesome', 'hdr': 'high dynamic range', 'fo': 'for',
    'op ti really': 'oneplus really', 'one plus ph': 'oneplus phone', 'spr': 'super', 'apprehension': 'appreciation',
    'max': 'maximum', 'oxygen o': 'oxygen os', 'kinda': 'kind of', 'medio': 'mediocre', 'btw': 'by the way', 'assam': 'awesome',
    'ph': 'phone', 'bos': 'range boost', 'beast': 'best', 'dlr': 'dslr', 'batter': 'better', 'cod': 'call of duty', 'nyc': 'nice',
    'unvilevebale item': 'unbelievable item', 'supper': 'super', 'op': 'oneplus', 'assume': 'awesome',
    'osm dolly atoms': 'awesome dolby atmos', 'mic failed': 'microphone failed', 'premium paper': 'premium feel', 'ver': 'very',
    'gonna': 'going to', 'pub': 'pubg', 'gun': 'good', 'jus': 'just', 'ive': 'i have', 'extent': 'excellent', 'nice hoon': 'nice phone',
    'gr': 'great', 'math': 'match', 'bt': 'but', 'ok':'okay', 'costa': 'costar', 'beast': 'best', 'hr': 'hour', 'sha': 'should',
    'wk': 'week', "hadnt": "had not", "im": "i am", "havent": "have not", "hasnt": "has not", 'u': "you", 'r': "are",
    "ui": "user interface", "doesnt": "does not", 'rambling': "rumbling", "io": "iphone operating system", 
    "sot": "special operation team", "le": "less", "fhd": "full high definition", "dont": "do not",
    "cam": "camera", "came": "camera", "avg": "average", "yea": "yeah", "lil": "little", 
    "costlier": "more expensive", "it's": "it is", "very": "very", "n": "and", "cant": "cannot", "dis": "this", "v": "we", 
    "hdr": 'high dynamic range', "didnt": "did not", "ive": "i have", "bezel": "bezel", "ur": "your", "wont": 'will not', 
    "hd": 'high definition', 'cleanui': "clean user interface", "tatics": "haptics", "sd": "secure digital", "gen": "generation", 
    "usp": 'unique selling proposition', 'degc': "degree celsius", "tatic": "haptic", "unbuilt": "inbuilt", 'xiomi': "xiaomi",
    'regreating': "regretting", 'fyi': "for your information", 'issuehrs': "issue hours", 'doomed': "zoomed",
    'ois': "optical image stabilization", 'theyll': "they will", 'ig': "instagram", 'bbd': "bigger better deal", 'cemra': "camera", 
    'fastly': "fast", "optimise": 'optimize', 'osum': 'awesome', 'vi': "vodafone", 'upi': "unified payments interface",
    'eyeturner': "eye turner", 'banger': "banger", 're': "resolution", 'goddamn': "goddamn", 'aint': "am not", 'plesently': "pleasantly", 
    'thik': "think", "tooo": "too", "uisvery": 'user interface very', 'gif': "graphics interchange format", 'siz': "six", 
    'costlier': "costlier", 'iphones': "iphone", 'youre': 'you are', 'doubtbut': "doubt but", 'phome': "phone", 'red': "redmi", 
    'okif': "okay if", 'pic': "picture", 'smatter': 'smarter', 'membrane': "ambrane", "holdnew": 'hold new', 'swine': "swipe", 
    'inshot': "inshot", 'pixelated': "pixel related", 'cameraai': "camera artificial intelligence", 'oppos': 'oppo', 'amaze': "amazing", 
    'daytoday': "day to day", 'offmy': "off my", 'laggy': "lag", 'victus': "victus", 'slowlike': "slow like",
    'wholeday': "full day", 'commendable': "recommendable", 'baku': "vaku", 
    'beat': "best", 'surfed': "suffered", 'bgmi': "battle ground mobile india", 'isnt': "is not", 
    'flickering': "flickering", 'least': "at least", 'doun': "down", 'thats': "that is", 'ill': "i will", 'bout': "about", 
    'butter': "better", 'emi': "equated monthly installment", 'prefect': "perfect", 'ketone': "keyone", 
    'ie': "in other words", 'cuz': "because", "youve": "you have", 'ott': "over the top", 
    'oct': "october", 'ois': "optical image stabilization", 'ip': "iphone", 'nowhope': "now hope", 'red': "redmi",
    "eraserunblur": "eraser focus", "wifi": "wireless fidelity", 'ok': "okay", 'hiccup': "hiccup",
    'janso': "january so", 'mahmaybe': "milliampere hour may be", 'lovable': "lovable", 'etc': "et cetera", "karma": "varma",
    'dayyyyyyyy': "day", 'pic': "picture", 'camra': "camera", 'Vry': "very", 'easilllyy': "easily",
    'came': "camera", 'mob': "mobile", 'flipcard': "flipkart", 'Kkk': "okay", 'swimmer': 'shimmery', 'supeeeeer': 'super', 'ur': 'your', 'nais': 'nice', 'descent': 'decent', 'se user': 'super', 'nris': 'nice',
    'suuuuuuuuuuuuuuper': 'super', 'project': 'product', 'xtra': 'extra', 'userniterface': 'user interface', 'prossecer': 'processor', 'amazingest': 'amazing',
    'col': 'color', 'superbbbbb': 'superb', 'goog': 'good', 'censor': 'sensor', 'ram': 'ram', 'wwwhhhoooooooo': 'who', 'pictre': 'picture', 'comera': 'camera', 'fa': 'for',
    'truely': 'truly', 'fonnne': 'phone', 'excellant': 'excellent', 'totallly': 'totally', 'ceramicback': 'ceramic back', 'internat': 'internet', 'iui': 'miui', 'camaera': 'camera', 'supper': 'super',
    'exllent': 'excellent', 'magnafiqui': 'magnificent', 'affecfordble': 'affordable', 'smmmmooooothhhhhh': 'smooth', 'veryg': 'very good', 'camaera': 'camera',
    'ar': 'are', 'eet': 'get', 'june': 'june', 'ster': 'star', 'osam': 'awesome', 'gona': 'gonna', 'suchh': 'such', 'amoled': 'amoled', 'fon': 'phone', 'ram': 'ram', 'exp': 'expensive',
    'xclent': 'excellent', 'ans': 'and', 'shotcut': 'shortcut', 'expoerience': 'experience', 'bgmi': 'battle grounds mobile india', 'anr': 'and', 'whao': 'wow', 'awesomeeee': 'awesome', 'blurr': 'blur',
    'definately': 'definitely', 'suuuuper': 'super', 'nize': 'nice', 'phobe': 'phone', 'thanksflipcart': 'thanks flipkart', 'mimax': 'mi max', 'picure': 'picture', 'blutooth': 'bluetooth', 'qhy': 'why',
    'user interfce': 'user interface', 'beasutiful': 'beautiful', 'smother': 'smoother', 'gooddd': 'good', 'ramgood': 'ram good', 'smother': 'smoother', 'suggestable': 'suggestible', 'gamesro': 'games to',
    'playbles': 'playable', 'fes': 'fest', 'crystalclear': 'crystal clear', 'ph': 'phone', 'frimeware': 'firmware', 'dowload': 'download', 'camara': 'camera', 'gud': 'good', 'jio': 'jio', 'againflipkart': 'again flipkart',
    'imposible': 'impossible', 'comfortbale': 'comfortable', 'whith': 'with', 'chages': 'changes', 'consiser': 'consider', 'heatsup': 'heats up', 'grt': 'great', 'fringerprint': 'fingerprint', 'detailingg': 'detailing',
    'gud': 'good', 'hz': 'hertz', 'nd': 'and', 'soundcollage': 'sound quality', 'wi': 'with', 'appreciateble': 'appreciable', 'phn': 'phone', 'mu': 'music', 'preforance': 'performance', 'veryyy': 'very',
    'ceramicback': 'ceramic back', 'ceraicback': 'ceramic back', 'battrey': 'battery', 'hollywow': 'hollywood', 'expirence': 'experience', 'niceui': 'nice user interface', 'terriffic': 'terrific', 'varien': 'variant',
    'xcellent': 'excellent', 'sorring': 'scoring', 'comfrtable': 'comfortable', 'mics': 'microphones', 'cds': 'cd', 'whot': 'what', 'mindbloing': 'mind blowing', 'gamesome': 'games on', 'fluently': 'fluent',
    'dat': 'that', 'amasing': 'amazing', 'superrr': 'super', 'osm': 'awesome', 'hreat': 'great', 'costefficeint': 'cost efficient', 'bhaskar': 'bhaskaran', 'heatingproblem': 'heating problem',
    'miracast': 'miracast', 'definately': 'definitely', 'wo': 'would', 'thsnks': 'thanks', 'whywhy': 'why why', 'cam': 'camera', 'gaurantee': 'guarantee', 'crazychaging': 'crazy charging',
    'interfece': 'interface', 'excellant': 'excellent', 'intenation': 'internet', 'bettry': 'battery', 'exellent': 'excellent', 'lockscreen': 'lock screen', 'tap': 'tap', 'eb': 'is',
    'cam': 'camera', 'exellent': 'excellent', 'pros': 'pros', 'cus': 'because', 'definatly': 'definitely', 'microphoneon': 'microphone on', 'renaining': 'remaining', 'nxet': 'next',
    'switcher': 'switcher', 'yooo': 'yo', 'exlent': 'excellent', 'vol': 'volume', 'magic': 'magic', 'beacuse': 'because', 'ven': 'even', 'expence': 'expense', 'pones': 'phones',
    'pu': 'pubg', 'exlent': 'excellent', 'bgmi': 'battle ground mobile india', 'athir': 'arshad', 'ramaining': 'remaining', 'docing': 'docking', 'batterylife': 'battery life', 'batt': 'battery', 
    'cas': 'case', 'proble': 'problem', 'sa': 'sa', 'lense': 'lens', 'cameraof': 'camera of', 'parformance': 'performance', 'whatsapp': 'whatsapp', 'camra': 'camera', 'amoleddisplay': 'amoled display',
    'hugh': 'high', 'exellent': 'excellent', 'phon': 'phone', 'boaring': 'boring', 'sync': 'sync', 'flipkart': 'flipkart', 'tp': 'to', 'displayflipkart': 'display flipkart', 'flipcart': 'flipkart',
    'complain': 'complain', 'sdgen': 'snapdragon generation', 'comerabgmi': 'camera battle ground mobile india', 'doint': 'do not', 'iys': 'it is', 'superp': 'super', 'expeeience': 'experience', 'loook': 'look',
    'couple': 'couple', 'phoneflipkart': 'phone flipkart', 'got': 'got', 'consisency': 'consistency', 'dispkay': 'display', 'proc': 'processor', 'gud': 'good', 'clarityclearity': 'clarity', 'octo': 'octa',
    'excessive': 'excessive', 'goodem': 'good em', 'snapdragon': 'snapdragon', 'camara': 'camera', 'sper': 'super', 'rebooting': 'rebooting', 'accessorry': 'accessory', 'usr': 'user', 'dispkay': 'display',
    'pictureclarity': 'picture clarity', 'dispkayclarity': 'display clarity', 'extremely': 'extremely', 'awsome': 'awesome', 'goodcamera': 'good camera', 'goodclatrity': 'good clarity', 'miui': 'miui',
    'clearn': 'clear', 'cllick': 'click', 'reseting': 'resetting', 'psl': 'psl', 'edxtra': 'extra', 'redmy': 'redmi', 'gamy': 'game', 'biometrics': 'biometrics', 'noney': 'money', 'lenovo': 'lenovo',
    'possessing': 'processing', 'ossam': 'awesome', 'tis': 'this', 'surport': 'support', 'awsom': 'awesome', 'supere': 'super', 'serviceflipkart': 'service flipkart', 'awesomeas': 'awesome', 'greate': 'great',
    'mobs': 'mobile', 'sept': 'september', 'its': 'its', 'wasawsm': 'was awesome', 'flipkartgood': 'flipkart good', 'easeofuse': 'ease of use', 'mi': 'mi', 'perfectperfect': 'perfect', 'ohow': 'oh how',
    'dosn': 'does', 'okkay': 'okay', 'awdome': 'awesome', 'des': 'des', 'awesomefeature': 'awesome feature', 'circa': 'circa', 'gud': 'good', 'backca': 'back cover', 'yhe': 'the', 'niceproduct': 'nice product',
    'me':'mi', 'awesomegod': 'awesome', 'tricking': 'tricking', 'allure': 'allure', 'mia1': 'mi a1', 'backpanel': 'back panel', 'microwave': 'microphone', 'fri': 'friend', 'frusterating': 'frustrating','moto':'motorola',
    'rs': 'rs', 'chat': 'chat', 'saiz': 'size', 'ram': 'ram', 'workswll': 'works well', 'mid': 'mi', 'ph': 'phone', 'flpkrt': 'flipkart', 'blowming': 'blowing', 'complaince': 'complain', 'ar': 'are', 'phn': 'phone',
    'usb': 'usb', 'coverback': 'cover back', 'awesomecamera': 'awesome camera', 'osame': 'awesome', 'bat': 'battery', 'weighing': 'weighing', 'midrange': 'mid range', 'blowng': 'blowing', 'yoursite': 'your site',
    'superbg': 'superb', 'intetnet': 'internet', 'besutiful': 'beautiful', 'suuuper': 'super', 'ate': 'ate', 'ceramicback': 'ceramic back', 'velvet': 'velvet', 'goog': 'good', 'doeswork': 'does work', 'interrface': 'interface',
    'spellings': 'spellings', 'competetion': 'competition', 'clarityis': 'clarity is', 'xclent': 'excellent', 'crome': 'chrome', 'sinply': 'simply', 'cermaic': 'ceramic', 'plz': 'please', 'compability': 'compatibility',
    'excellnt': 'excellent', 'iui': 'miui', 'ultraa': 'ultra', 'whatsoever': 'whatsoever', 'goodand': 'good and', 'gotcamera': 'got camera', 'ple': 'please', 'afortable': 'affordable', 'kns': 'kms', 'nicefeature': 'nice feature',
    'redemi': 'redmi', 'xxent': 'excellent', 'cuttrt': 'cutout', 'mi': 'mi', 'serires': 'series', 'whish': 'wish', 'dlexo': 'deluxe', 'cristal': 'crystal', 'makesense': 'make sense', 'gud': 'good', 'expellience': 'experience',
    'reflectiion': 'reflection', 'microphone': 'microphone', 'cameraquality': 'camera quality', 'awesomef': 'awesome', 'guddisplay': 'good display', 'frustrting': 'frustrating', 'vol': 'volume', 'cermaic': 'ceramic', 'clearence': 'clearance', 
    'snapdragon': 'snapdragon', 'ceramicback': 'ceramic back', 'cermaicback': 'ceramic back', 'snapdragon820': 'snapdragon 820', 'miui8': 'miui 8', 'snapdragon': 'snapdragon', 'snapdragon': 'snapdragon', 'snapdragon835': 'snapdragon 835', 'snapdragon820': 'snapdragon 820'
}
# Replace abbreviations in the Reviews column
for abbrev, full_form in abbreviation_dict.items():
    # Use word boundaries to ensure whole words are replaced
    df['Reviews'] = df['Reviews'].str.replace(r'\b' + abbrev + r'\b', full_form, case=False, regex=True)

unwanted_words = [
    'euuuuuuuuuuuuuu', 'imei', 'xx', 'o', 'p', 'k', 'x', 'w', 'st', 'isbn', 'gb', 'min', 'mah', 'x x x', 'makhan',
    'bim', 'rd', 'r', 'n', 'nd', 'mm', 'fish', 'apple ka bar', 'mp', 'ppi', 'yrr', 'imei', 'k', 'science', 'x', 'nd',
    'rd', 'le', 'st', 'p', 'pm', 'f', 'tho', 'h', 'th', 'gn', 'xr', 'xl', 'am', 'tg', 'p', 'z', 'ce', 'ip', 'lt', 'td',
    'gt', 'lea', 'la', 'der', 'ir', 'j', 'sp', 'th', 'v', 'cg', 'wee', 'seg', 'g', 'pro', 'x', 'p', 'e', 'opt', 'nfc',
    'tm', 'ir', 'xnd', 'ffd', 'htc', 'cal', 'pm', 'ordo', 'gh', 'rn', 'mia', 'ip', 'sd', 'oct', 'core', 'expos', 'rd',
    'ip', 'pe', 'amp', 'paisa bassol', 'pc', 'al', 'zindabad', 'dnd', 'rsk', 'g', 'ooooooo', 'mmmmmmm', 'ggggggg', 'vfd',
    'havoc', 'ah', 'hi', 'hai', 'swimming', 'gop', 'ji', 'lajawab', 'asap loose', 'ie', 'h ago', 'madathukulam', 'mo', 
    'fea', 'l', 'ex', 'qu', 'Lotus', 'voodoo', 'ko', 'ont', 'maa', 'ag', 'ne', 'quot', 'sakuntala', 'rayagada bissamcuttack',
    'gimmick', 'thi', 'str', 'fatafati', 'mast', 'garcia jharkhand', 'sa', 'isvudn', 'x', 'sg', 'hijab', 'tbh', 'wars', 
    'nts', 'huawei', 'keirin', 'ofc', 'pg', 'sec', 'jaar', 'hai ye', 'th', 'ft', 'emu', 'gpu', 'fr', 'nit', 'eis', 'oo',
    'hh', 'ly', 'fei', 'q', 'c', 'sw', 'kd', 'ofc', 'bl', 'lol', 'et', 'rgh', 'extremewwe', 'dts', 'iu', 'vr', 'Soo', 
    'al', 'sm', 'rsk', 'eta', 'gh', 'nu', 'ota', 'fp'
]
# Remove unwanted words
for word in unwanted_words:
    df['Reviews'] = df['Reviews'].str.replace(r'\b' + word + r'\b', '', case=False, regex=True)

# Save the updated DataFrame to a new CSV file
output_file_path = r"C:\Users\Elakkiya\Downloads\flipkart\motorola_reviews_final.csv"
df.to_csv(output_file_path, index=False)

print("Data cleaned and saved successfully.")
# Out:
# Data cleaned and saved successfully.

# %%
'moto':'motorola',lg:life good, cheerzzz:cheers,plz:please,mei:me,worthy:worth,gente:generation,amd:and,lte:light,mid:middle,
awestruck:awesome struck.abt:about,tat:that,dis:this,,gente:generation,v:we,r:are,exppos:exynos,ill:i will,ad:advertisement.realm:realme,
sd:snapdragon,bickering:flickering,ex:example,lcd:liquid crystal display,fyi:for your information,hd:high definition,mio:mimo, even tho:even though,
wowwwwww:wow,redmipocohonor:redmi poco honor,epxiernce:experience,opt:option,jan:january,oct:october,phonemes:phone,portthats:port thats,
battery profane :battery performance,ram:random access memory,rom:read only memory,hasn:has not,spec:specification,nsa:non standalone,
sa:signal antenna,god:good,camarabut:camera but,awsmrest:awesome rest,surfing:suffering,androidmoto:android motorola,
topnotchperformance:top notch performance,tommoro:tomorrow,his friend :after few,avg:average,

# %%
'x','p','e','opt','nfc','tm','ir','xnd','ffd','htc','cal','pm','ordo','gh','rn','mia','ip','sd','oct','core','expos','rd','ip','pe','amp','paisa bassol','pc','al','zindabad','dnd','rsk','g','ooooooo',
'mmmmmmm','ggggggg','vfd','havoc','ah','hi','hai','swimming','gop','ji','lajawab','asap loose','ie','h ago'

# %%
    'moto': 'motorola', 'lg': 'life good', 'cheerzzz': 'cheers', 'plz': 'please', 'mei': 'me', 'worthy': 'worth', 'gente': 'generation',
    'amd': 'and','lte': 'light','mid': 'middle','awestruck': 'awesome struck','abt': 'about','tat': 'that','dis': 'this','v': 'we',
    'r': 'are','exppos': 'exynos','ill': 'i will','ad': 'advertisement','realm': 'realme','sd': 'snapdragon','bickering': 'flickering',
    'ex': 'example','lcd': 'liquid crystal display','fyi': 'for your information','hd': 'high definition','mio': 'mimo',
    'even tho': 'even though', 'wowwwwww': 'wow', 'redmipocohonor': 'redmi poco honor', 'epxiernce': 'experience', 'opt': 'option',
    'jan': 'january','oct': 'october','phonemes': 'phone','portthats': 'port thats','battery profane': 'battery performance',
    'ram': 'random access memory','rom': 'read only memory','hasn': 'has not','spec': 'specification','nsa': 'non standalone',
    'sa': 'signal antenna', 'god': 'good','camarabut': 'camera but','awsmrest': 'awesome rest','surfing': 'suffering',
    'androidmoto': 'android motorola','topnotchperformance': 'top notch performance','tommoro': 'tomorrow',
    'his friend': 'after few','avg': 'average','knot': 'okay not', 'mod': 'mode', 'pho': 'phone', 'phine': 'phone', 'west': 'waste', 'dayyyyyyyy': 'day', 'parfomes':'performance', 'imp': 'important',
           'swimmer': 'shimmery', 'gam': 'game', 'goodcamra': 'good camera', 'spec': 'specification', 'performancedont': 'performance do not', 'mobileoppof': 'mobile oppo',
           'colitis': 'quality', 'priformence': 'performence', 'ny': 'nice', 'goodmobail': 'good mobile', 'product…': 'product', 'performancegoo': 'performance',
           'superrrrr': 'super', 'coma': 'come', 'ju': 'just', 'gotoofficewithstyle': 'go to office with style', 'supervooc': 'super', 'feb': 'february', 'pais': 'money',
           'lightning': 'lightening', 'lestvice': 'quality best', 'fischer': 'feature', 'slick': 'slim'

# %%
{'knot': 'okay not', 'mod': 'mode', 'pho': 'phone', 'phine': 'phone', 'west': 'waste', 'dayyyyyyyy': 'day', 'parfomes':'performance', 'imp': 'important',
           'swimmer': 'shimmery', 'gam': 'game', 'goodcamra': 'good camera', 'spec': 'specification', 'performancedont': 'performance do not', 'mobileoppof': 'mobile oppo',
           'colitis': 'quality', 'priformence': 'performence', 'ny': 'nice', 'goodmobail': 'good mobile', 'product…': 'product', 'performancegoo': 'performance',
           'superrrrr': 'super', 'coma': 'come', 'ju': 'just', 'gotoofficewithstyle': 'go to office with style', 'supervooc': 'super', 'feb': 'february', 'pais': 'money',
           'lightning': 'lightening', 'lestvice': 'quality best', 'fischer': 'feature', 'slick': 'slim']
           
remove_words = ['madathukulam', 'mo', 'fea', 'l', 'ex', 'qu', 'Lotus', 'voodoo', 'ko', 'ont', 'maa', 'ag', 'ne', 'quot','sakuntala', 'rayagada bissamcuttack',
               'gimmick','thi', 'str', 'fatafati', 'mast', 'garcia jharkhand', 'sa', 'isvudn']

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import emoji

# Load the data
file_path = r"C:\Users\Elakkiya\Downloads\flipkart\google_merged.csv"
df = pd.read_csv(file_path)

# Handle missing values
# Drop rows where the Reviews text is missing
df.dropna(subset=['Review'], inplace=True)

# Ensure all entries in the Reviews column are strings
df['Review'] = df['Review'].astype(str)

# Remove emojis using the emoji library
def remove_emojis(text):
    return emoji.replace_emoji(text, replace='')

# Remove special characters and digits
def remove_special_characters(text):
    return re.sub('[^a-zA-Z\s]', '', text)

# Normalize the text
def normalize_text(text):
    text = text.lower()  # Convert to lowercase
    text = remove_emojis(text)
    text = remove_special_characters(text)
    text = re.sub('\s+', ' ', text)  # Remove extra spaces
    return text

# Apply normalization
df['Cleaned_Review'] = df['Review'].apply(normalize_text)

# Remove stopwords
stop_words = set(stopwords.words('english'))
df['Cleaned_Review'] = df['Cleaned_Review'].apply(lambda x: ' '.join([word for word in x.split() if word not in stop_words]))

# Apply lemmatization
lemmatizer = WordNetLemmatizer()
df['Cleaned_Review'] = df['Cleaned_Review'].apply(lambda x: ' '.join([lemmatizer.lemmatize(word) for word in x.split()]))

# Save the cleaned data to a new CSV file
output_file_path = r"C:\Users\Elakkiya\Downloads\flipkart\google_reviews_cleaned.csv"
df.to_csv(output_file_path, index=False)

print("Data cleaning completed and saved to", output_file_path)
# Out:
# Data cleaning completed and saved to C:\Users\Elakkiya\Downloads\flipkart\google_reviews_cleaned.csv

# %%
import pandas as pd
from autocorrect import Speller

# Load the data
file_path = r"C:\Users\Elakkiya\Downloads\flipkart\google_reviews_cleaned.csv"
df = pd.read_csv(file_path)# Apply autocorrect using autocorrect library
spell = Speller(lang='en')

def correct_spelling(text):
    return ' '.join([spell(word) for word in text.split()])

df['Autocorrected_Review'] = df['Cleaned_Review'].apply(correct_spelling)

# Save the cleaned data to a new CSV file
output_file_path = r"C:\Users\Elakkiya\Downloads\flipkart\google_reviews_autocorrected.csv"
df.to_csv(output_file_path, index=False)

print("Data cleaning and spell correction completed and saved to", output_file_path)
# Out:
# Data cleaning and spell correction completed and saved to C:\Users\Elakkiya\Downloads\flipkart\google_reviews_autocorrected.csv

# %%
import pandas as pd
import re

# Load the cleaned data
file_path = r"C:\Users\Elakkiya\Downloads\flipkart\google_reviews_autocorrected.csv"
df = pd.read_csv(file_path)

# Create a new column 'Reviews' based on 'Autocorrected_Reviews'
df['Reviews'] = df['Autocorrected_Review']

# Dictionary of specific abbreviations and their corrections
abbreviation_dict = {
    'camara': 'camera', 'fps': 'frames per second', 'oplus': 'oneplus', 'sd gen': 'snapdragon generation', 'superb': 'super',
    'professor': 'processor', 'sound college': 'sound quality', 'dam': 'damn', 'opp': 'oppo', 'aws': 'awesome',
    'vry gd': 'very good', 'supppoppp': 'super', 'prosesar': 'processor', 'approx hr sot': 'approximately hour screen on time',
    'u': 'you', 'hr': 'hour', 'prosper': 'processor', 'usa': 'usage', 'good pro': 'good product', 'gd': 'good',
    'nice prod': 'nice product', 'p': 'performance', 'ui': 'user interface', 'day us': 'day usage', 'prosesar': 'processor',
    'flipcart': 'flipkart', 'battery beast': 'battery best', 'ease': 'easy', 'pub': 'pubg', 'osm': 'awesome',
    'worth karma worthuuu': 'worth the money', 'ois': 'optical image stabilization', 'aim happy': 'i am happy',
    'pub cod': 'pubg, call of duty', 'hz': 'hertz', 'degree census': 'degree celsius', 'nd': 'and',
    'hit issue': 'heating issue', 'ai': 'artificial intelligence', 'wil': 'will', 'tax': 'thanks', 'anthem': 'item',
    'mint camera': 'main camera', 'heat throttle': 'heating and throttling', 'ill update': 'i will update',
    'phone devils aswoome': 'phone device is awesome', 'hdr': 'high dynamic range', 'fo': 'for',
    'op ti really': 'oneplus really', 'one plus ph': 'oneplus phone', 'spr': 'super', 'apprehension': 'appreciation',
    'max': 'maximum', 'oxygen o': 'oxygen os', 'kinda': 'kind of', 'medio': 'mediocre', 'btw': 'by the way', 'assam': 'awesome',
    'ph': 'phone', 'bos': 'range boost', 'beast': 'best', 'dlr': 'dslr', 'batter': 'better', 'cod': 'call of duty', 'nyc': 'nice',
    'unvilevebale item': 'unbelievable item', 'supper': 'super', 'op': 'oneplus', 'assume': 'awesome',
    'osm dolly atoms': 'awesome dolby atmos', 'mic failed': 'microphone failed', 'premium paper': 'premium feel', 'ver': 'very',
    'gonna': 'going to', 'pub': 'pubg', 'gun': 'good', 'jus': 'just', 'ive': 'i have', 'extent': 'excellent', 'nice hoon': 'nice phone',
    'gr': 'great', 'math': 'match', 'bt': 'but', 'ok':'okay', 'costa': 'costar', 'beast': 'best', 'hr': 'hour', 'sha': 'should',
    'wk': 'week', "hadnt": "had not", "im": "i am", "havent": "have not", "hasnt": "has not", 'u': "you", 'r': "are",
    "ui": "user interface", "doesnt": "does not", 'rambling': "rumbling", "io": "iphone operating system", 
    "sot": "special operation team", "le": "less", "fhd": "full high definition", "dont": "do not",
    "cam": "camera", "came": "camera", "avg": "average", "yea": "yeah", "lil": "little", 
    "costlier": "more expensive", "it's": "it is", "very": "very", "n": "and", "cant": "cannot", "dis": "this", "v": "we", 
    "hdr": 'high dynamic range', "didnt": "did not", "ive": "i have", "bezel": "bezel", "ur": "your", "wont": 'will not', 
    "hd": 'high definition', 'cleanui': "clean user interface", "tatics": "haptics", "sd": "secure digital", "gen": "generation", 
    "usp": 'unique selling proposition', 'degc': "degree celsius", "tatic": "haptic", "unbuilt": "inbuilt", 'xiomi': "xiaomi",
    'regreating': "regretting", 'fyi': "for your information", 'issuehrs': "issue hours", 'doomed': "zoomed",
    'ois': "optical image stabilization", 'theyll': "they will", 'ig': "instagram", 'bbd': "bigger better deal", 'cemra': "camera", 
    'fastly': "fast", "optimise": 'optimize', 'osum': 'awesome', 'vi': "vodafone", 'upi': "unified payments interface",
    'eyeturner': "eye turner", 'banger': "banger", 're': "resolution", 'goddamn': "goddamn", 'aint': "am not", 'plesently': "pleasantly", 
    'thik': "think", "tooo": "too", "uisvery": 'user interface very', 'gif': "graphics interchange format", 'siz': "six", 
    'costlier': "costlier", 'iphones': "iphone", 'youre': 'you are', 'doubtbut': "doubt but", 'phome': "phone", 'red': "redmi", 
    'okif': "okay if", 'pic': "picture", 'smatter': 'smarter', 'membrane': "ambrane", "holdnew": 'hold new', 'swine': "swipe", 
    'inshot': "inshot", 'pixelated': "pixel related", 'cameraai': "camera artificial intelligence", 'oppos': 'oppo', 'amaze': "amazing", 
    'daytoday': "day to day", 'offmy': "off my", 'laggy': "lag", 'victus': "victus", 'slowlike': "slow like",
    'wholeday': "full day", 'commendable': "recommendable", 'baku': "vaku", 
    'beat': "best", 'surfed': "suffered", 'bgmi': "battle ground mobile india", 'isnt': "is not", 
    'flickering': "flickering", 'least': "at least", 'doun': "down", 'thats': "that is", 'ill': "i will", 'bout': "about", 
    'butter': "better", 'emi': "equated monthly installment", 'prefect': "perfect", 'ketone': "keyone", 
    'ie': "in other words", 'cuz': "because", "youve": "you have", 'ott': "over the top", 
    'oct': "october", 'ois': "optical image stabilization", 'ip': "iphone", 'nowhope': "now hope", 'red': "redmi",
    "eraserunblur": "eraser focus", "wifi": "wireless fidelity", 'ok': "okay", 'hiccup': "hiccup",
    'janso': "january so", 'mahmaybe': "milliampere hour may be", 'lovable': "lovable", 'etc': "et cetera", "karma": "varma",
    'dayyyyyyyy': "day", 'pic': "picture", 'camra': "camera", 'Vry': "very", 'easilllyy': "easily",
    'came': "camera", 'mob': "mobile", 'flipcard': "flipkart", 'Kkk': "okay", 'swimmer': 'shimmery', 'supeeeeer': 'super', 'ur': 'your', 'nais': 'nice', 'descent': 'decent', 'se user': 'super', 'nris': 'nice',
    'suuuuuuuuuuuuuuper': 'super', 'project': 'product', 'xtra': 'extra', 'userniterface': 'user interface', 'prossecer': 'processor', 'amazingest': 'amazing',
    'col': 'color', 'superbbbbb': 'superb', 'goog': 'good', 'censor': 'sensor', 'ram': 'ram', 'wwwhhhoooooooo': 'who', 'pictre': 'picture', 'comera': 'camera', 'fa': 'for',
    'truely': 'truly', 'fonnne': 'phone', 'excellant': 'excellent', 'totallly': 'totally', 'ceramicback': 'ceramic back', 'internat': 'internet', 'iui': 'miui', 'camaera': 'camera', 'supper': 'super',
    'exllent': 'excellent', 'magnafiqui': 'magnificent', 'affecfordble': 'affordable', 'smmmmooooothhhhhh': 'smooth', 'veryg': 'very good', 'camaera': 'camera',
    'ar': 'are', 'eet': 'get', 'june': 'june', 'ster': 'star', 'osam': 'awesome', 'gona': 'gonna', 'suchh': 'such', 'amoled': 'amoled', 'fon': 'phone', 'ram': 'ram', 'exp': 'expensive',
    'xclent': 'excellent', 'ans': 'and', 'shotcut': 'shortcut', 'expoerience': 'experience', 'bgmi': 'battle grounds mobile india', 'anr': 'and', 'whao': 'wow', 'awesomeeee': 'awesome', 'blurr': 'blur',
    'definately': 'definitely', 'suuuuper': 'super', 'nize': 'nice', 'phobe': 'phone', 'thanksflipcart': 'thanks flipkart', 'mimax': 'mi max', 'picure': 'picture', 'blutooth': 'bluetooth', 'qhy': 'why',
    'user interfce': 'user interface', 'beasutiful': 'beautiful', 'smother': 'smoother', 'gooddd': 'good', 'ramgood': 'ram good', 'smother': 'smoother', 'suggestable': 'suggestible', 'gamesro': 'games to',
    'playbles': 'playable', 'fes': 'fest', 'crystalclear': 'crystal clear', 'ph': 'phone', 'frimeware': 'firmware', 'dowload': 'download', 'camara': 'camera', 'gud': 'good', 'jio': 'jio', 'againflipkart': 'again flipkart',
    'imposible': 'impossible', 'comfortbale': 'comfortable', 'whith': 'with', 'chages': 'changes', 'consiser': 'consider', 'heatsup': 'heats up', 'grt': 'great', 'fringerprint': 'fingerprint', 'detailingg': 'detailing',
    'gud': 'good', 'hz': 'hertz', 'nd': 'and', 'soundcollage': 'sound quality', 'wi': 'with', 'appreciateble': 'appreciable', 'phn': 'phone', 'mu': 'music', 'preforance': 'performance', 'veryyy': 'very',
    'ceramicback': 'ceramic back', 'ceraicback': 'ceramic back', 'battrey': 'battery', 'hollywow': 'hollywood', 'expirence': 'experience', 'niceui': 'nice user interface', 'terriffic': 'terrific', 'varien': 'variant',
    'xcellent': 'excellent', 'sorring': 'scoring', 'comfrtable': 'comfortable', 'mics': 'microphones', 'cds': 'cd', 'whot': 'what', 'mindbloing': 'mind blowing', 'gamesome': 'games on', 'fluently': 'fluent',
    'dat': 'that', 'amasing': 'amazing', 'superrr': 'super', 'osm': 'awesome', 'hreat': 'great', 'costefficeint': 'cost efficient', 'bhaskar': 'bhaskaran', 'heatingproblem': 'heating problem',
    'miracast': 'miracast', 'definately': 'definitely', 'wo': 'would', 'thsnks': 'thanks', 'whywhy': 'why why', 'cam': 'camera', 'gaurantee': 'guarantee', 'crazychaging': 'crazy charging',
    'interfece': 'interface', 'excellant': 'excellent', 'intenation': 'internet', 'bettry': 'battery', 'exellent': 'excellent', 'lockscreen': 'lock screen', 'tap': 'tap', 'eb': 'is',
    'cam': 'camera', 'exellent': 'excellent', 'pros': 'pros', 'cus': 'because', 'definatly': 'definitely', 'microphoneon': 'microphone on', 'renaining': 'remaining', 'nxet': 'next',
    'switcher': 'switcher', 'yooo': 'yo', 'exlent': 'excellent', 'vol': 'volume', 'magic': 'magic', 'beacuse': 'because', 'ven': 'even', 'expence': 'expense', 'pones': 'phones',
    'pu': 'pubg', 'exlent': 'excellent', 'bgmi': 'battle ground mobile india', 'athir': 'arshad', 'ramaining': 'remaining', 'docing': 'docking', 'batterylife': 'battery life', 'batt': 'battery', 
    'cas': 'case', 'proble': 'problem', 'sa': 'sa', 'lense': 'lens', 'cameraof': 'camera of', 'parformance': 'performance', 'whatsapp': 'whatsapp', 'camra': 'camera', 'amoleddisplay': 'amoled display',
    'hugh': 'high', 'exellent': 'excellent', 'phon': 'phone', 'boaring': 'boring', 'sync': 'sync', 'flipkart': 'flipkart', 'tp': 'to', 'displayflipkart': 'display flipkart', 'flipcart': 'flipkart',
    'complain': 'complain', 'sdgen': 'snapdragon generation', 'comerabgmi': 'camera battle ground mobile india', 'doint': 'do not', 'iys': 'it is', 'superp': 'super', 'expeeience': 'experience', 'loook': 'look',
    'couple': 'couple', 'phoneflipkart': 'phone flipkart', 'got': 'got', 'consisency': 'consistency', 'dispkay': 'display', 'proc': 'processor', 'gud': 'good', 'clarityclearity': 'clarity', 'octo': 'octa',
    'excessive': 'excessive', 'goodem': 'good em', 'snapdragon': 'snapdragon', 'camara': 'camera', 'sper': 'super', 'rebooting': 'rebooting', 'accessorry': 'accessory', 'usr': 'user', 'dispkay': 'display',
    'pictureclarity': 'picture clarity', 'dispkayclarity': 'display clarity', 'extremely': 'extremely', 'awsome': 'awesome', 'goodcamera': 'good camera', 'goodclatrity': 'good clarity', 'miui': 'miui',
    'clearn': 'clear', 'cllick': 'click', 'reseting': 'resetting', 'psl': 'psl', 'edxtra': 'extra', 'redmy': 'redmi', 'gamy': 'game', 'biometrics': 'biometrics', 'noney': 'money', 'lenovo': 'lenovo',
    'possessing': 'processing', 'ossam': 'awesome', 'tis': 'this', 'surport': 'support', 'awsom': 'awesome', 'supere': 'super', 'serviceflipkart': 'service flipkart', 'awesomeas': 'awesome', 'greate': 'great',
    'mobs': 'mobile', 'sept': 'september', 'its': 'its', 'wasawsm': 'was awesome', 'flipkartgood': 'flipkart good', 'easeofuse': 'ease of use', 'mi': 'mi', 'perfectperfect': 'perfect', 'ohow': 'oh how',
    'dosn': 'does', 'okkay': 'okay', 'awdome': 'awesome', 'des': 'des', 'awesomefeature': 'awesome feature', 'circa': 'circa', 'gud': 'good', 'backca': 'back cover', 'yhe': 'the', 'niceproduct': 'nice product',
    'me':'mi', 'awesomegod': 'awesome', 'tricking': 'tricking', 'allure': 'allure', 'mia1': 'mi a1', 'backpanel': 'back panel', 'microwave': 'microphone', 'fri': 'friend', 'frusterating': 'frustrating','moto':'motorola',
    'rs': 'rs', 'chat': 'chat', 'saiz': 'size', 'ram': 'ram', 'workswll': 'works well', 'mid': 'mi', 'ph': 'phone', 'flpkrt': 'flipkart', 'blowming': 'blowing', 'complaince': 'complain', 'ar': 'are', 'phn': 'phone',
    'usb': 'usb', 'coverback': 'cover back', 'awesomecamera': 'awesome camera', 'osame': 'awesome', 'bat': 'battery', 'weighing': 'weighing', 'midrange': 'mid range', 'blowng': 'blowing', 'yoursite': 'your site',
    'superbg': 'superb', 'intetnet': 'internet', 'besutiful': 'beautiful', 'suuuper': 'super', 'ate': 'ate', 'ceramicback': 'ceramic back', 'velvet': 'velvet', 'goog': 'good', 'doeswork': 'does work', 'interrface': 'interface',
    'spellings': 'spellings', 'competetion': 'competition', 'clarityis': 'clarity is', 'xclent': 'excellent', 'crome': 'chrome', 'sinply': 'simply', 'cermaic': 'ceramic', 'plz': 'please', 'compability': 'compatibility',
    'excellnt': 'excellent', 'iui': 'miui', 'ultraa': 'ultra', 'whatsoever': 'whatsoever', 'goodand': 'good and', 'gotcamera': 'got camera', 'ple': 'please', 'afortable': 'affordable', 'kns': 'kms', 'nicefeature': 'nice feature',
    'redemi': 'redmi', 'xxent': 'excellent', 'cuttrt': 'cutout', 'mi': 'mi', 'serires': 'series', 'whish': 'wish', 'dlexo': 'deluxe', 'cristal': 'crystal', 'makesense': 'make sense', 'gud': 'good', 'expellience': 'experience',
    'reflectiion': 'reflection', 'microphone': 'microphone', 'cameraquality': 'camera quality', 'awesomef': 'awesome', 'guddisplay': 'good display', 'frustrting': 'frustrating', 'vol': 'volume', 'cermaic': 'ceramic', 'clearence': 'clearance', 
    'snapdragon': 'snapdragon', 'ceramicback': 'ceramic back', 'cermaicback': 'ceramic back', 'snapdragon820': 'snapdragon 820', 'miui8': 'miui 8', 'snapdragon': 'snapdragon', 'snapdragon': 'snapdragon', 'snapdragon835': 'snapdragon 835', 'snapdragon820': 'snapdragon 820'
}
# Replace abbreviations in the Reviews column
for abbrev, full_form in abbreviation_dict.items():
    # Use word boundaries to ensure whole words are replaced
    df['Reviews'] = df['Reviews'].str.replace(r'\b' + abbrev + r'\b', full_form, case=False, regex=True)

unwanted_words = [
    'euuuuuuuuuuuuuu', 'imei', 'xx', 'o', 'p', 'k', 'x', 'w', 'st', 'isbn', 'gb', 'min', 'mah', 'x x x', 'makhan',
    'bim', 'rd', 'r', 'n', 'nd', 'mm', 'fish', 'apple ka bar', 'mp', 'ppi', 'yrr', 'imei', 'k', 'science', 'x', 'nd',
    'rd', 'le', 'st', 'p', 'pm', 'f', 'tho', 'h', 'th', 'gn', 'xr', 'xl', 'am', 'tg', 'p', 'z', 'ce', 'ip', 'lt', 'td',
    'gt', 'lea', 'la', 'der', 'ir', 'j', 'sp', 'th', 'v', 'cg', 'wee', 'seg', 'g', 'pro', 'x', 'p', 'e', 'opt', 'nfc',
    'tm', 'ir', 'xnd', 'ffd', 'htc', 'cal', 'pm', 'ordo', 'gh', 'rn', 'mia', 'ip', 'sd', 'oct', 'core', 'expos', 'rd',
    'ip', 'pe', 'amp', 'paisa bassol', 'pc', 'al', 'zindabad', 'dnd', 'rsk', 'g', 'ooooooo', 'mmmmmmm', 'ggggggg', 'vfd',
    'havoc', 'ah', 'hi', 'hai', 'swimming', 'gop', 'ji', 'lajawab', 'asap loose', 'ie', 'h ago', 'madathukulam', 'mo', 
    'fea', 'l', 'ex', 'qu', 'Lotus', 'voodoo', 'ko', 'ont', 'maa', 'ag', 'ne', 'quot', 'sakuntala', 'rayagada bissamcuttack',
    'gimmick', 'thi', 'str', 'fatafati', 'mast', 'garcia jharkhand', 'sa', 'isvudn', 'x', 'sg', 'hijab', 'tbh', 'wars', 
    'nts', 'huawei', 'keirin', 'ofc', 'pg', 'sec', 'jaar', 'hai ye', 'th', 'ft', 'emu', 'gpu', 'fr', 'nit', 'eis', 'oo',
    'hh', 'ly', 'fei', 'q', 'c', 'sw', 'kd', 'ofc', 'bl', 'lol', 'et', 'rgh', 'extremewwe', 'dts', 'iu', 'vr', 'Soo', 
    'al', 'sm', 'rsk', 'eta', 'gh', 'nu', 'ota', 'fp'
]
# Remove unwanted words
for word in unwanted_words:
    df['Reviews'] = df['Reviews'].str.replace(r'\b' + word + r'\b', '', case=False, regex=True)

# Save the updated DataFrame to a new CSV file
output_file_path = r"C:\Users\Elakkiya\Downloads\flipkart\google_reviews_final.csv"
df.to_csv(output_file_path, index=False)

print("Data cleaned and saved successfully.")
# Out:
# Data cleaned and saved successfully.

# %%
import pandas as pd
import glob

# List of file paths to combine
file_paths = [
    r"C:\Users\Elakkiya\Downloads\flipkart\motorola_reviews_final.csv",
    r"C:\Users\Elakkiya\Downloads\flipkart\oneplus_reviews_final.csv",
    r"C:\Users\Elakkiya\Downloads\flipkart\Honor_reviews_final.csv",
    r"C:\Users\Elakkiya\Downloads\flipkart\google_reviews_final.csv",
    r"C:\Users\Elakkiya\Downloads\flipkart\oppo_reviews_final.csv",
]

# Initialize an empty list to hold DataFrames
dfs = []

# Read each file and append the DataFrame to the list
for file_path in file_paths:
    df = pd.read_csv(file_path)
    dfs.append(df)

# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat(dfs, ignore_index=True)

# Drop rows with missing values
combined_df.dropna(inplace=True)

# Drop specified columns
columns_to_drop = ['Autocorrected_Review', 'Product_Link', 'Product_Price', 'Cleaned_Review', 'Review']
combined_df.drop(columns=columns_to_drop, inplace=True, errors='ignore')

# Rename the specified columns
columns_to_rename = {'Rating': 'Ratings'}
combined_df.rename(columns=columns_to_rename, inplace=True)

# Count the number of duplicate rows
duplicate_count = combined_df.duplicated(keep=False).sum()
print(f"Number of duplicate rows: {duplicate_count}")

# Drop duplicate rows
combined_df.drop_duplicates(inplace=True)

# Save the combined DataFrame to a new CSV file
output_file_path = r"C:\Users\Elakkiya\Downloads\flipkart\Flipkart_Products_reviews.csv"
combined_df.to_csv(output_file_path, index=False)

print("Combined DataFrame created successfully and saved.")
# Out:
# Number of duplicate rows: 1005
# Combined DataFrame created successfully and saved.

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Elakkiya\Downloads\flipkart\Flipkart_Products_reviews.csv")
df
# Out:
#                                 Product_Name  Ratings  \
# 0      MOTOROLA Edge 50 (Peach Fuzz, 256 GB)      4.0
# 1      MOTOROLA Edge 50 (Peach Fuzz, 256 GB)      4.0
# 2      MOTOROLA Edge 50 (Peach Fuzz, 256 GB)      5.0
# 3      MOTOROLA Edge 50 (Peach Fuzz, 256 GB)      4.0
# 4      MOTOROLA Edge 50 (Peach Fuzz, 256 GB)      5.0
# ...                                      ...      ...
# 9520  OPPO Reno11 Pro 5G (Rock Grey, 256 GB)      5.0
# 9521  OPPO Reno11 Pro 5G (Rock Grey, 256 GB)      5.0
# 9522  OPPO Reno11 Pro 5G (Rock Grey, 256 GB)      1.0
# 9523  OPPO Reno11 Pro 5G (Rock Grey, 256 GB)      5.0
# 9524  OPPO Reno11 Pro 5G (Rock Grey, 256 GB)      5.0
#
#                                                 Reviews
# 0      crisp display camera performed way better exp...
# 1     one day review  awesome design awesome camera ...
# 2     could recommend best price range clean user in...
# 3                 camera best mobile phone heating much
# 4     phone come ram boost get turning get hand make...
# ...                                                 ...
# 9520                                    good phone love
# 9521                                         great look
# 9522                       front camera good lost money
# 9523                                              super
# 9524                                look like well slim
#
# [9525 rows x 3 columns]

# %%
df['Product_ID'] = pd.factorize(df['Product_Name'])[0] + 1

# %%
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk

# Step 1: Download VADER lexicon (only needed once)
# nltk.download('vader_lexicon')

# Step 2: Load your DataFrame from the CSV file
input_file_path = r"C:\Users\Elakkiya\Downloads\flipkart\Flipkart_Products_reviews.csv"
df = pd.read_csv(input_file_path)

# Creating a Product_ID column by factorizing Product_Name
df['Product_ID'] = pd.factorize(df['Product_Name'])[0] + 1

# Step 3: Initialize VADER Sentiment Analyzer
sia = SentimentIntensityAnalyzer()

# Step 4: Define a function to get sentiment scores
def get_sentiment(review):
    sentiment = sia.polarity_scores(review)
    return sentiment['compound']  # Returning the compound score

# Step 5: Apply the function to the Review column
df['Sentiment_Score'] = df['Reviews'].apply(get_sentiment)

# Step 6: Classify sentiment as Positive, Negative, or Neutral
df['Sentiment'] = df['Sentiment_Score'].apply(
    lambda score: 'Positive' if score > 0.05 else ('Negative' if score < -0.05 else 'Neutral')
)

# Step 7: Save the DataFrame to a CSV file
output_file_path = "Flipkart_Products_reviews_with_sentiment.csv"
df.to_csv(output_file_path, index=False)

print(f'Sentiment analysis results saved to {output_file_path}')
# Out:
# Sentiment analysis results saved to Flipkart_Products_reviews_with_sentiment.csv

# %%
df=pd.read_csv(r"C:\Users\Elakkiya\Downloads\flipkart\Flipkart_Products_reviews_with_sentiment.csv")

# %%
df[df['Sentiment'] == 'Negative']
# Out:
#                                                              Product_Name  \
# 26                                  MOTOROLA Edge 50 (Peach Fuzz, 256 GB)
# 31                                  MOTOROLA Edge 50 (Peach Fuzz, 256 GB)
# 72                                  MOTOROLA Edge 50 (Koala Grey, 256 GB)
# 77                                  MOTOROLA Edge 50 (Koala Grey, 256 GB)
# 332                        Motorola Edge 50 Fusion (Forest Green, 256 GB)
# 338                        Motorola Edge 50 Fusion (Forest Green, 128 GB)
# 412                               MOTOROLA Edge 50 (Jungle Green, 256 GB)
# 417                               MOTOROLA Edge 50 (Jungle Green, 256 GB)
# 446        Motorola Edge 50 Pro 5G with 125W Charger (Caneel Bay, 256 GB)
# 496     Motorola Edge 50 Pro 5G with 125W Charger (Vanilla Cream, 256 GB)
# 538      Motorola Edge 50 Pro 5G with 68W Charger (Luxe Lavender, 256 GB)
# 539      Motorola Edge 50 Pro 5G with 68W Charger (Luxe Lavender, 256 GB)
# 588    Motorola Edge 50 Pro 5G with 68W Charger (Moonlight Pearl, 256 GB)
# 589    Motorola Edge 50 Pro 5G with 68W Charger (Moonlight Pearl, 256 GB)
# 656                    Motorola Edge 50 Fusion (Marshmallow Blue, 256 GB)
# 662                            Motorola Edge 50 Fusion (Hot Pink, 128 GB)
# 710                         Motorola Edge 50 Fusion (Forest Blue, 128 GB)
# 772      Motorola Edge 50 Pro 5G with 125W Charger (Black Beauty, 256 GB)
# 852                            Motorola Edge 50 Fusion (Hot Pink, 256 GB)
# 902                         Motorola Edge 50 Fusion (Forest Blue, 256 GB)
# 908                    Motorola Edge 50 Fusion (Marshmallow Blue, 128 GB)
# 970     Motorola Edge 50 Pro 5G with 125W Charger (Luxe Lavender, 256 GB)
# 1020  Motorola Edge 50 Pro 5G with 125W Charger (Moonlight Pearl, 256 GB)
# 1082      Motorola Edge 50 Pro 5G with 68W Charger (Black Beauty, 256 GB)
# 1083      Motorola Edge 50 Pro 5G with 68W Charger (Black Beauty, 256 GB)
# 1127                            Motorola Edge 40 Neo (Peach Fuzz, 128 GB)
# 1145                            Motorola Edge 40 Neo (Peach Fuzz, 128 GB)
# 1227                          Motorola Edge 40 Neo (Soothing Sea, 128 GB)
# 1245                          Motorola Edge 40 Neo (Soothing Sea, 128 GB)
# 1327                            Motorola Edge 40 Neo (Caneel Bay, 128 GB)
# 1345                            Motorola Edge 40 Neo (Caneel Bay, 128 GB)
# 1427                          Motorola Edge 40 Neo (Black Beauty, 128 GB)
# 1445                          Motorola Edge 40 Neo (Black Beauty, 128 GB)
# 1478                             Motorola Edge 40 (Eclipse Black, 256 GB)
# 1499                             Motorola Edge 40 (Eclipse Black, 256 GB)
# 1528                              Motorola Edge 40 (Nebula Green, 256 GB)
# 1549                              Motorola Edge 40 (Nebula Green, 256 GB)
# 1578                                Motorola Edge 40 (Lunar Blue, 256 GB)
# 1599                                Motorola Edge 40 (Lunar Blue, 256 GB)
# 1723                                    Motorola g72 (Polar Blue, 128 GB)
# 1773                                Motorola g72 (Meteorite Grey, 128 GB)
# 1882                              Motorola Edge 30 (Aurora Green, 128 GB)
# 1906                                  MOTOROLA g82 5G(White Lily, 128 GB)
# 1982                               Motorola Edge 30 (Meteor Grey, 128 GB)
# 2177                              Motorola Edge 40 (Viva Magenta, 256 GB)
# 2198                              Motorola Edge 40 (Viva Magenta, 256 GB)
# 2313                     Motorola Edge 30 Ultra (Starlight White, 256 GB)
# 2328                     Motorola Edge 30 Ultra (Starlight White, 256 GB)
# 2342                     Motorola Edge 30 Ultra (Starlight White, 256 GB)
# 2348                     Motorola Edge 30 Ultra (Starlight White, 256 GB)
# 2363                  Motorola Edge 30 Ultra (Interstellar Black, 256 GB)
# 2378                  Motorola Edge 30 Ultra (Interstellar Black, 256 GB)
# 2392                  Motorola Edge 30 Ultra (Interstellar Black, 256 GB)
# 2398                  Motorola Edge 30 Ultra (Interstellar Black, 256 GB)
# 2442                     Motorola Edge 30 Ultra (Starlight White, 128 GB)
# 2492                  Motorola Edge 30 Ultra (Interstellar Black, 128 GB)
# 2537                               Motorola G62 5G (Frosted Blue, 128 GB)
# 2586                              Motorola G62 5G (Midnight Gray, 128 GB)
# 2834                           Motorola Edge 20 5G (Frosted Onyx, 128 GB)
# 2879                              MOTOROLA G71 5G (Neptune Green, 128 GB)
# 2934                          Motorola Edge 20 5G (Frosted Pearl, 128 GB)
# 2984                        Motorola Edge 20 5G (Frosted Emerald, 128 GB)
# 3001                       Motorola Edge 20 Pro 5G (Midnight Sky, 128 GB)
# 3012                       Motorola Edge 20 Pro 5G (Midnight Sky, 128 GB)
# 3037                       Motorola Edge 20 Pro 5G (Midnight Sky, 128 GB)
# 3038                       Motorola Edge 20 Pro 5G (Midnight Sky, 128 GB)
# 3051                   Motorola Edge 20 Pro 5G (Iridescent Cloud, 128 GB)
# 3062                   Motorola Edge 20 Pro 5G (Iridescent Cloud, 128 GB)
# 3087                   Motorola Edge 20 Pro 5G (Iridescent Cloud, 128 GB)
# 3088                   Motorola Edge 20 Pro 5G (Iridescent Cloud, 128 GB)
# 3286                           MOTOROLA Moto G 5G (Volcanic Grey, 128 GB)
# 3336                          MOTOROLA Moto G 5G (Frosted Silver, 128 GB)
# 3346             MOTOROLA Motorola One Vision (Sapphire Gradient, 128 GB)
# 3441                              MOTOROLA Moto X4 (Sterling Blue, 64 GB)
# 3522                            OnePlus Nord CE4 (Celadon Marble, 128 GB)
# 3596                            OnePlus Nord CE4 (Celadon Marble, 128 GB)
# 3626                            OnePlus Nord CE4 (Celadon Marble, 128 GB)
# 3643                               OnePlus Nord CE4 (Dark Chrome, 128 GB)
# 3717                               OnePlus Nord CE4 (Dark Chrome, 128 GB)
# 3747                               OnePlus Nord CE4 (Dark Chrome, 128 GB)
# 3808                             OnePlus Nord 3 5G (Tempest Gray, 128 GB)
# 3848                             OnePlus Nord 3 5G (Tempest Gray, 128 GB)
# 3861                             OnePlus Nord 3 5G (Tempest Gray, 128 GB)
# 3862                             OnePlus Nord 3 5G (Tempest Gray, 128 GB)
# 3864                             OnePlus Nord 3 5G (Tempest Gray, 128 GB)
# 3869                             OnePlus Nord 3 5G (Tempest Gray, 128 GB)
# 3895                             OnePlus Nord 3 5G (Tempest Gray, 128 GB)
# 3939                            OnePlus Nord CE4 (Celadon Marble, 256 GB)
# 4013                            OnePlus Nord CE4 (Celadon Marble, 256 GB)
# 4043                            OnePlus Nord CE4 (Celadon Marble, 256 GB)
# 4064                                   OnePlus Nord (Blue Marble, 128 GB)
# 4070                                   OnePlus Nord (Blue Marble, 128 GB)
# 4072                                   OnePlus Nord (Blue Marble, 128 GB)
# 4087                                   OnePlus Nord (Blue Marble, 256 GB)
# 4092                                   OnePlus Nord (Blue Marble, 256 GB)
# 4143                                   OnePlus 7T Pro (Haze Blue, 256 GB)
# 4149                                   OnePlus 7T Pro (Haze Blue, 256 GB)
# 4151                                   OnePlus 7T Pro (Haze Blue, 256 GB)
# 4159                                    OnePlus Nord (Blue Marble, 64 GB)
# 4296                                       OnePlus 8 (Onyx Black, 256 GB)
# 4514                                    OnePlus 8 (Glacial Green, 128 GB)
# 4522                                    OnePlus 8 (Glacial Green, 128 GB)
# 4534                                    OnePlus 8 (Glacial Green, 128 GB)
# 4547                                    OnePlus 8 (Glacial Green, 128 GB)
# 4551                               OnePlus Nord CE 5G (Blue Void, 256 GB)
# 4559                               OnePlus Nord CE 5G (Blue Void, 256 GB)
# 4575                               OnePlus Nord CE 5G (Blue Void, 256 GB)
# 4576                               OnePlus Nord CE 5G (Blue Void, 256 GB)
# 4577                               OnePlus Nord CE 5G (Blue Void, 256 GB)
# 4578                               OnePlus Nord CE 5G (Blue Void, 256 GB)
# 4579                               OnePlus Nord CE 5G (Blue Void, 256 GB)
# 4580                               OnePlus Nord CE 5G (Blue Void, 256 GB)
# 4582                               OnePlus Nord CE 5G (Blue Void, 256 GB)
# 4583                               OnePlus Nord CE 5G (Blue Void, 256 GB)
# 4606                                       OnePlus 8 (Onyx Black, 128 GB)
# 4614                                       OnePlus 8 (Onyx Black, 128 GB)
# 4626                                       OnePlus 8 (Onyx Black, 128 GB)
# 4639                                       OnePlus 8 (Onyx Black, 128 GB)
# 4675                                    OnePlus 8 (Glacial Green, 256 GB)
# 4711                                OnePlus 8 (Interstellar Glow, 256 GB)
# 4828                                   Honor X9b (Midnight Black, 256 GB)
# 4834                                   Honor X9b (Midnight Black, 256 GB)
# 4835                                   Honor X9b (Midnight Black, 256 GB)
# 4847                                   Honor X9b (Midnight Black, 256 GB)
# 4849                                   Honor X9b (Midnight Black, 256 GB)
# 4870                                 Honor 90 5G (Diamond Silver, 512 GB)
# 4875                                 Honor 90 5G (Diamond Silver, 512 GB)
# 4911                                 Honor 90 5G (Diamond Silver, 512 GB)
# 4915                                 Honor 90 5G (Diamond Silver, 512 GB)
# 4924                                 Honor 90 5G (Diamond Silver, 512 GB)
# 4926                                 Honor 90 5G (Diamond Silver, 512 GB)
# 4928                                 Honor 90 5G (Diamond Silver, 512 GB)
# 4930                                 Honor 90 5G (Diamond Silver, 512 GB)
# 4948                                   Honor X9b (Sunrise Orange, 256 GB)
# 4954                                   Honor X9b (Sunrise Orange, 256 GB)
# 4955                                   Honor X9b (Sunrise Orange, 256 GB)
# 4967                                   Honor X9b (Sunrise Orange, 256 GB)
# 4969                                   Honor X9b (Sunrise Orange, 256 GB)
# 4990                                 Honor 90 5G (Midnight Black, 512 GB)
# 4995                                 Honor 90 5G (Midnight Black, 512 GB)
# 5031                                 Honor 90 5G (Midnight Black, 512 GB)
# 5035                                 Honor 90 5G (Midnight Black, 512 GB)
# 5044                                 Honor 90 5G (Midnight Black, 512 GB)
# 5046                                 Honor 90 5G (Midnight Black, 512 GB)
# 5048                                 Honor 90 5G (Midnight Black, 512 GB)
# 5050                                 Honor 90 5G (Midnight Black, 512 GB)
# 5078                                  Honor 90 5G (Emerald Green, 512 GB)
# 5083                                  Honor 90 5G (Emerald Green, 512 GB)
# 5119                                  Honor 90 5G (Emerald Green, 512 GB)
# 5123                                  Honor 90 5G (Emerald Green, 512 GB)
# 5132                                  Honor 90 5G (Emerald Green, 512 GB)
# 5134                                  Honor 90 5G (Emerald Green, 512 GB)
# 5136                                  Honor 90 5G (Emerald Green, 512 GB)
# 5138                                  Honor 90 5G (Emerald Green, 512 GB)
# 5240                                   Honor Play (Midnight Black, 64 GB)
# 5322                                   Honor Play (Midnight Black, 64 GB)
# 5324                                   Honor Play (Midnight Black, 64 GB)
# 5346                                 Honor 90 5G (Midnight Black, 256 GB)
# 5377                                 Honor 90 5G (Midnight Black, 256 GB)
# 5379                                 Honor 90 5G (Midnight Black, 256 GB)
# 5380                                 Honor 90 5G (Midnight Black, 256 GB)
# 5383                                 Honor 90 5G (Midnight Black, 256 GB)
# 5386                                 Honor 90 5G (Midnight Black, 256 GB)
# 5407                                   Honor Play (Midnight Black, 64 GB)
# 5503                                        Honor Play (Navy Blue, 64 GB)
# 5585                                        Honor Play (Navy Blue, 64 GB)
# 5587                                        Honor Play (Navy Blue, 64 GB)
# 5608                                        Honor Play (Navy Blue, 64 GB)
# 5853                                          Honor 6 Plus (Black, 32 GB)
# 5857                                          Honor 6 Plus (Black, 32 GB)
# 5858                                          Honor 6 Plus (Black, 32 GB)
# 5861                                          Honor 6 Plus (Black, 32 GB)
# 5868                                          Honor 6 Plus (Black, 32 GB)
# 5872                                          Honor 6 Plus (Black, 32 GB)
# 5876                                          Honor 6 Plus (Black, 32 GB)
# 5956                                 Honor 8 Pro (Midnight Black, 128 GB)
# 6056                                      Honor 8 Pro (Navy Blue, 128 GB)
# 6095                                 Honor 90 5G (Diamond Silver, 256 GB)
# 6126                                 Honor 90 5G (Diamond Silver, 256 GB)
# 6128                                 Honor 90 5G (Diamond Silver, 256 GB)
# 6129                                 Honor 90 5G (Diamond Silver, 256 GB)
# 6132                                 Honor 90 5G (Diamond Silver, 256 GB)
# 6135                                 Honor 90 5G (Diamond Silver, 256 GB)
# 6190                                   Google Pixel 7a (Charcoal, 128 GB)
# 6206                                   Google Pixel 7a (Charcoal, 128 GB)
# 6218                                   Google Pixel 7a (Charcoal, 128 GB)
# 6241                                   Google Pixel 7a (Charcoal, 128 GB)
# 6244                                   Google Pixel 7a (Charcoal, 128 GB)
# 6277                                   Google Pixel 7a (Charcoal, 128 GB)
# 6289                                   Google Pixel 7a (Charcoal, 128 GB)
# 6348                                       Google Pixel 7a (Snow, 128 GB)
# 6364                                       Google Pixel 7a (Snow, 128 GB)
# 6376                                       Google Pixel 7a (Snow, 128 GB)
# 6399                                       Google Pixel 7a (Snow, 128 GB)
# 6402                                       Google Pixel 7a (Snow, 128 GB)
# 6435                                       Google Pixel 7a (Snow, 128 GB)
# 6447                                       Google Pixel 7a (Snow, 128 GB)
# 6506                                      Google Pixel 7a (Coral, 128 GB)
# 6522                                      Google Pixel 7a (Coral, 128 GB)
# 6534                                      Google Pixel 7a (Coral, 128 GB)
# 6557                                      Google Pixel 7a (Coral, 128 GB)
# 6560                                      Google Pixel 7a (Coral, 128 GB)
# 6593                                      Google Pixel 7a (Coral, 128 GB)
# 6605                                      Google Pixel 7a (Coral, 128 GB)
# 6633                                        Google Pixel 8 (Mint, 128 GB)
# 6715                                        Google Pixel 8 (Mint, 128 GB)
# 6720                                        Google Pixel 8 (Mint, 128 GB)
# 6727                                        Google Pixel 8 (Mint, 128 GB)
# 6729                                        Google Pixel 8 (Mint, 128 GB)
# 6731                                        Google Pixel 8 (Mint, 128 GB)
# 6738                                        Google Pixel 8 (Mint, 128 GB)
# 6739                                        Google Pixel 8 (Mint, 128 GB)
# 6765                                       Google Pixel 8 (Hazel, 128 GB)
# 6847                                       Google Pixel 8 (Hazel, 128 GB)
# 6852                                       Google Pixel 8 (Hazel, 128 GB)
# 6859                                       Google Pixel 8 (Hazel, 128 GB)
# 6861                                       Google Pixel 8 (Hazel, 128 GB)
# 6863                                       Google Pixel 8 (Hazel, 128 GB)
# 6870                                       Google Pixel 8 (Hazel, 128 GB)
# 6871                                       Google Pixel 8 (Hazel, 128 GB)
# 6897                                    Google Pixel 8 (Obsidian, 128 GB)
# 6979                                    Google Pixel 8 (Obsidian, 128 GB)
# 6984                                    Google Pixel 8 (Obsidian, 128 GB)
# 6991                                    Google Pixel 8 (Obsidian, 128 GB)
# 6993                                    Google Pixel 8 (Obsidian, 128 GB)
# 6995                                    Google Pixel 8 (Obsidian, 128 GB)
# 7002                                    Google Pixel 8 (Obsidian, 128 GB)
# 7003                                    Google Pixel 8 (Obsidian, 128 GB)
# 7111                                    Google Pixel 7 (Obsidian, 128 GB)
# 7135                                    Google Pixel 7 (Obsidian, 128 GB)
# 7139                                    Google Pixel 7 (Obsidian, 128 GB)
# 7154                                    Google Pixel 7 (Obsidian, 128 GB)
# 7266                                  Google Pixel 7 (Lemongrass, 128 GB)
# 7290                                  Google Pixel 7 (Lemongrass, 128 GB)
# 7294                                  Google Pixel 7 (Lemongrass, 128 GB)
# 7309                                  Google Pixel 7 (Lemongrass, 128 GB)
# 7421                                        Google Pixel 7 (Snow, 128 GB)
# 7445                                        Google Pixel 7 (Snow, 128 GB)
# 7449                                        Google Pixel 7 (Snow, 128 GB)
# 7464                                        Google Pixel 7 (Snow, 128 GB)
# 7494                                        Google Pixel 8 (Rose, 128 GB)
# 7576                                        Google Pixel 8 (Rose, 128 GB)
# 7581                                        Google Pixel 8 (Rose, 128 GB)
# 7588                                        Google Pixel 8 (Rose, 128 GB)
# 7590                                        Google Pixel 8 (Rose, 128 GB)
# 7592                                        Google Pixel 8 (Rose, 128 GB)
# 7599                                        Google Pixel 8 (Rose, 128 GB)
# 7600                                        Google Pixel 8 (Rose, 128 GB)
# 7622                               OPPO F25 Pro 5G (Coral Purple, 128 GB)
# 7626                               OPPO F25 Pro 5G (Coral Purple, 128 GB)
# 7628                               OPPO F25 Pro 5G (Coral Purple, 128 GB)
# 7649                               OPPO F25 Pro 5G (Coral Purple, 128 GB)
# 7686                               OPPO F25 Pro 5G (Coral Purple, 128 GB)
# 7695                               OPPO F25 Pro 5G (Coral Purple, 128 GB)
# 7698                               OPPO F25 Pro 5G (Coral Purple, 128 GB)
# 7701                               OPPO F25 Pro 5G (Coral Purple, 128 GB)
# 7709                               OPPO F25 Pro 5G (Coral Purple, 128 GB)
# 7717                               OPPO F25 Pro 5G (Coral Purple, 128 GB)
# 7735                                 OPPO F25 Pro 5G (Ocean Blue, 256 GB)
# 7739                                 OPPO F25 Pro 5G (Ocean Blue, 256 GB)
# 7741                                 OPPO F25 Pro 5G (Ocean Blue, 256 GB)
# 7762                                 OPPO F25 Pro 5G (Ocean Blue, 256 GB)
# 7799                                 OPPO F25 Pro 5G (Ocean Blue, 256 GB)
# 7808                                 OPPO F25 Pro 5G (Ocean Blue, 256 GB)
# 7811                                 OPPO F25 Pro 5G (Ocean Blue, 256 GB)
# 7814                                 OPPO F25 Pro 5G (Ocean Blue, 256 GB)
# 7822                                 OPPO F25 Pro 5G (Ocean Blue, 256 GB)
# 7830                                 OPPO F25 Pro 5G (Ocean Blue, 256 GB)
# 7848                                 OPPO F25 Pro 5G (Ocean Blue, 128 GB)
# 7852                                 OPPO F25 Pro 5G (Ocean Blue, 128 GB)
# 7854                                 OPPO F25 Pro 5G (Ocean Blue, 128 GB)
# 7875                                 OPPO F25 Pro 5G (Ocean Blue, 128 GB)
# 7912                                 OPPO F25 Pro 5G (Ocean Blue, 128 GB)
# 7921                                 OPPO F25 Pro 5G (Ocean Blue, 128 GB)
# 7924                                 OPPO F25 Pro 5G (Ocean Blue, 128 GB)
# 7927                                 OPPO F25 Pro 5G (Ocean Blue, 128 GB)
# 7935                                 OPPO F25 Pro 5G (Ocean Blue, 128 GB)
# 7943                                 OPPO F25 Pro 5G (Ocean Blue, 128 GB)
# 7961                                   OPPO F25 Pro 5G (Lava Red, 128 GB)
# 7965                                   OPPO F25 Pro 5G (Lava Red, 128 GB)
# 7967                                   OPPO F25 Pro 5G (Lava Red, 128 GB)
# 7988                                   OPPO F25 Pro 5G (Lava Red, 128 GB)
# 8025                                   OPPO F25 Pro 5G (Lava Red, 128 GB)
# 8034                                   OPPO F25 Pro 5G (Lava Red, 128 GB)
# 8037                                   OPPO F25 Pro 5G (Lava Red, 128 GB)
# 8040                                   OPPO F25 Pro 5G (Lava Red, 128 GB)
# 8048                                   OPPO F25 Pro 5G (Lava Red, 128 GB)
# 8056                                   OPPO F25 Pro 5G (Lava Red, 128 GB)
# 8067                                    OPPO F27 Pro+ (Dusk Pink, 128 GB)
# 8087                                    OPPO F27 Pro+ (Dusk Pink, 128 GB)
# 8092                                    OPPO F27 Pro+ (Dusk Pink, 128 GB)
# 8093                                    OPPO F27 Pro+ (Dusk Pink, 128 GB)
# 8105                                    OPPO F27 Pro+ (Dusk Pink, 128 GB)
# 8110                                    OPPO F27 Pro+ (Dusk Pink, 128 GB)
# 8114                                    OPPO F27 Pro+ (Dusk Pink, 128 GB)
# 8120                                    OPPO F27 Pro+ (Dusk Pink, 128 GB)
# 8124                                    OPPO F27 Pro+ (Dusk Pink, 128 GB)
# 8126                                    OPPO F27 Pro+ (Dusk Pink, 128 GB)
# 8136                                    OPPO F27 Pro+ (Dusk Pink, 128 GB)
# 8146                                OPPO F27 Pro+ (Midnight Navy, 256 GB)
# 8166                                OPPO F27 Pro+ (Midnight Navy, 256 GB)
# 8171                                OPPO F27 Pro+ (Midnight Navy, 256 GB)
# 8172                                OPPO F27 Pro+ (Midnight Navy, 256 GB)
# 8184                                OPPO F27 Pro+ (Midnight Navy, 256 GB)
# 8189                                OPPO F27 Pro+ (Midnight Navy, 256 GB)
# 8193                                OPPO F27 Pro+ (Midnight Navy, 256 GB)
# 8199                                OPPO F27 Pro+ (Midnight Navy, 256 GB)
# 8203                                OPPO F27 Pro+ (Midnight Navy, 256 GB)
# 8205                                OPPO F27 Pro+ (Midnight Navy, 256 GB)
# 8215                                OPPO F27 Pro+ (Midnight Navy, 256 GB)
# 8222                                  OPPO F27 5G (Emerald Green, 128 GB)
# 8286                              OPPO Reno8T 5G (Midnight Black, 128 GB)
# 8310                              OPPO Reno8T 5G (Midnight Black, 128 GB)
# 8460                           OPPO Reno10 Pro 5G (Glossy Purple, 256 GB)
# 8556                            OPPO Reno10 Pro 5G (Silvery Grey, 256 GB)
# 8672                                OPPO Reno8T 5G (Sunrise Gold, 128 GB)
# 8696                                OPPO Reno8T 5G (Sunrise Gold, 128 GB)
# 8734                                   OPPO Reno11 5G (Rock Grey, 256 GB)
# 8739                                   OPPO Reno11 5G (Rock Grey, 256 GB)
# 8758                                   OPPO Reno11 5G (Rock Grey, 256 GB)
# 8772                                   OPPO Reno11 5G (Rock Grey, 256 GB)
# 8782                                   OPPO Reno11 5G (Rock Grey, 256 GB)
# 8929                                  OPPO Reno11 5G (Wave Green, 128 GB)
# 8934                                  OPPO Reno11 5G (Wave Green, 128 GB)
# 8953                                  OPPO Reno11 5G (Wave Green, 128 GB)
# 8967                                  OPPO Reno11 5G (Wave Green, 128 GB)
# 8977                                  OPPO Reno11 5G (Wave Green, 128 GB)
# 9029                                 OPPO F21 Pro (Sunset Orange, 128 GB)
# 9061                                 OPPO F21 Pro (Sunset Orange, 128 GB)
# 9106                            OPPO F21s Pro 5G (Dawnlight Gold, 128 GB)
# 9121                            OPPO F21s Pro 5G (Dawnlight Gold, 128 GB)
# 9125                            OPPO F21s Pro 5G (Dawnlight Gold, 128 GB)
# 9133                            OPPO F21s Pro 5G (Dawnlight Gold, 128 GB)
# 9134                            OPPO F21s Pro 5G (Dawnlight Gold, 128 GB)
# 9148                            OPPO F21s Pro 5G (Dawnlight Gold, 128 GB)
# 9151                            OPPO F21s Pro 5G (Dawnlight Gold, 128 GB)
# 9157                            OPPO F21s Pro 5G (Dawnlight Gold, 128 GB)
# 9173                                   OPPO A78 5G (Glowing Blue, 128 GB)
# 9195                                   OPPO A78 5G (Glowing Blue, 128 GB)
# 9218                                   OPPO A78 5G (Glowing Blue, 128 GB)
# 9227                                   OPPO A78 5G (Glowing Blue, 128 GB)
# 9228                                   OPPO A78 5G (Glowing Blue, 128 GB)
# 9279                                OPPO Reno8 5G (Shimmer Black, 128 GB)
# 9286                                OPPO Reno8 5G (Shimmer Black, 128 GB)
# 9294                                OPPO Reno8 5G (Shimmer Black, 128 GB)
# 9378                                 OPPO Reno8 5G (Shimmer Gold, 128 GB)
# 9385                                 OPPO Reno8 5G (Shimmer Gold, 128 GB)
# 9393                                 OPPO Reno8 5G (Shimmer Gold, 128 GB)
# 9450                               OPPO Reno11 Pro 5G (Rock Grey, 256 GB)
# 9513                               OPPO Reno11 Pro 5G (Rock Grey, 256 GB)
#
#       Ratings  \
# 26        3.0
# 31        3.0
# 72        3.0
# 77        3.0
# 332       5.0
# 338       5.0
# 412       3.0
# 417       3.0
# 446       5.0
# 496       5.0
# 538       4.0
# 539       4.0
# 588       4.0
# 589       4.0
# 656       5.0
# 662       5.0
# 710       5.0
# 772       5.0
# 852       5.0
# 902       5.0
# 908       5.0
# 970       5.0
# 1020      5.0
# 1082      4.0
# 1083      4.0
# 1127      4.0
# 1145      4.0
# 1227      4.0
# 1245      4.0
# 1327      4.0
# 1345      4.0
# 1427      4.0
# 1445      4.0
# 1478      5.0
# 1499      3.0
# 1528      5.0
# 1549      3.0
# 1578      5.0
# 1599      3.0
# 1723      5.0
# 1773      5.0
# 1882      5.0
# 1906      4.0
# 1982      5.0
# 2177      5.0
# 2198      3.0
# 2313      4.0
# 2328      5.0
# 2342      3.0
# 2348      4.0
# 2363      4.0
# 2378      5.0
# 2392      3.0
# 2398      4.0
# 2442      5.0
# 2492      5.0
# 2537      4.0
# 2586      4.0
# 2834      4.0
# 2879      5.0
# 2934      4.0
# 2984      4.0
# 3001      5.0
# 3012      4.0
# 3037      4.0
# 3038      4.0
# 3051      5.0
# 3062      4.0
# 3087      4.0
# 3088      4.0
# 3286      4.0
# 3336      4.0
# 3346      5.0
# 3441      5.0
# 3522      4.0
# 3596      5.0
# 3626      5.0
# 3643      4.0
# 3717      5.0
# 3747      5.0
# 3808      3.0
# 3848      3.0
# 3861      3.0
# 3862      3.0
# 3864      3.0
# 3869      1.0
# 3895      5.0
# 3939      4.0
# 4013      5.0
# 4043      5.0
# 4064      1.0
# 4070      2.0
# 4072      1.0
# 4087      1.0
# 4092      1.0
# 4143      1.0
# 4149      1.0
# 4151      1.0
# 4159      1.0
# 4296      1.0
# 4514      5.0
# 4522      3.0
# 4534      1.0
# 4547      1.0
# 4551      3.0
# 4559      3.0
# 4575      1.0
# 4576      1.0
# 4577      3.0
# 4578      1.0
# 4579      1.0
# 4580      1.0
# 4582      1.0
# 4583      1.0
# 4606      5.0
# 4614      3.0
# 4626      1.0
# 4639      1.0
# 4675      1.0
# 4711      1.0
# 4828      3.0
# 4834      2.0
# 4835      2.0
# 4847      1.0
# 4849      1.0
# 4870      3.0
# 4875      5.0
# 4911      1.0
# 4915      2.0
# 4924      2.0
# 4926      1.0
# 4928      1.0
# 4930      1.0
# 4948      3.0
# 4954      2.0
# 4955      2.0
# 4967      1.0
# 4969      1.0
# 4990      3.0
# 4995      5.0
# 5031      1.0
# 5035      2.0
# 5044      2.0
# 5046      1.0
# 5048      1.0
# 5050      1.0
# 5078      3.0
# 5083      5.0
# 5119      1.0
# 5123      2.0
# 5132      2.0
# 5134      1.0
# 5136      1.0
# 5138      1.0
# 5240      5.0
# 5322      5.0
# 5324      4.0
# 5346      5.0
# 5377      1.0
# 5379      4.0
# 5380      1.0
# 5383      2.0
# 5386      1.0
# 5407      4.0
# 5503      5.0
# 5585      5.0
# 5587      4.0
# 5608      4.0
# 5853      4.0
# 5857      1.0
# 5858      1.0
# 5861      1.0
# 5868      1.0
# 5872      1.0
# 5876      1.0
# 5956      4.0
# 6056      4.0
# 6095      5.0
# 6126      1.0
# 6128      4.0
# 6129      1.0
# 6132      2.0
# 6135      1.0
# 6190      3.0
# 6206      2.0
# 6218      3.0
# 6241      2.0
# 6244      1.0
# 6277      2.0
# 6289      1.0
# 6348      3.0
# 6364      2.0
# 6376      3.0
# 6399      2.0
# 6402      1.0
# 6435      2.0
# 6447      1.0
# 6506      3.0
# 6522      2.0
# 6534      3.0
# 6557      2.0
# 6560      1.0
# 6593      2.0
# 6605      1.0
# 6633      5.0
# 6715      1.0
# 6720      1.0
# 6727      3.0
# 6729      2.0
# 6731      1.0
# 6738      1.0
# 6739      2.0
# 6765      5.0
# 6847      1.0
# 6852      1.0
# 6859      3.0
# 6861      2.0
# 6863      1.0
# 6870      1.0
# 6871      2.0
# 6897      5.0
# 6979      1.0
# 6984      1.0
# 6991      3.0
# 6993      2.0
# 6995      1.0
# 7002      1.0
# 7003      2.0
# 7111      3.0
# 7135      3.0
# 7139      2.0
# 7154      1.0
# 7266      3.0
# 7290      3.0
# 7294      2.0
# 7309      1.0
# 7421      3.0
# 7445      3.0
# 7449      2.0
# 7464      1.0
# 7494      5.0
# 7576      1.0
# 7581      1.0
# 7588      3.0
# 7590      2.0
# 7592      1.0
# 7599      1.0
# 7600      2.0
# 7622      5.0
# 7626      3.0
# 7628      3.0
# 7649      3.0
# 7686      3.0
# 7695      3.0
# 7698      1.0
# 7701      1.0
# 7709      1.0
# 7717      3.0
# 7735      5.0
# 7739      3.0
# 7741      3.0
# 7762      3.0
# 7799      3.0
# 7808      3.0
# 7811      1.0
# 7814      1.0
# 7822      1.0
# 7830      3.0
# 7848      5.0
# 7852      3.0
# 7854      3.0
# 7875      3.0
# 7912      3.0
# 7921      3.0
# 7924      1.0
# 7927      1.0
# 7935      1.0
# 7943      3.0
# 7961      5.0
# 7965      3.0
# 7967      3.0
# 7988      3.0
# 8025      3.0
# 8034      3.0
# 8037      1.0
# 8040      1.0
# 8048      1.0
# 8056      3.0
# 8067      3.0
# 8087      3.0
# 8092      1.0
# 8093      1.0
# 8105      1.0
# 8110      3.0
# 8114      1.0
# 8120      1.0
# 8124      1.0
# 8126      1.0
# 8136      2.0
# 8146      3.0
# 8166      3.0
# 8171      1.0
# 8172      1.0
# 8184      1.0
# 8189      3.0
# 8193      1.0
# 8199      1.0
# 8203      1.0
# 8205      1.0
# 8215      2.0
# 8222      2.0
# 8286      3.0
# 8310      4.0
# 8460      3.0
# 8556      3.0
# 8672      3.0
# 8696      4.0
# 8734      4.0
# 8739      3.0
# 8758      2.0
# 8772      5.0
# 8782      4.0
# 8929      4.0
# 8934      3.0
# 8953      2.0
# 8967      5.0
# 8977      4.0
# 9029      3.0
# 9061      3.0
# 9106      4.0
# 9121      1.0
# 9125      2.0
# 9133      2.0
# 9134      1.0
# 9148      1.0
# 9151      1.0
# 9157      1.0
# 9173      4.0
# 9195      3.0
# 9218      3.0
# 9227      1.0
# 9228      1.0
# 9279      5.0
# 9286      4.0
# 9294      5.0
# 9378      5.0
# 9385      4.0
# 9393      5.0
# 9450      3.0
# 9513      2.0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Reviews  \
# 26                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              photo quality good camera app lag slow irritating battery average does not last long enough fast charging also mark phone tremendous heating issue get heated charging video recording video calling taking picture also running app display phone really amazing disappointed
# 31                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                battery drainage quickly and heating problem
# 72                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              photo quality good camera app lag slow irritating battery average does not last long enough fast charging also mark phone tremendous heating issue get heated charging video recording video calling taking picture also running app display phone really amazing disappointed
# 77                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                battery drainage quickly and heating problem
# 332                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            first time us motorola smartphones go without hesitation every thing mark price segment ignore negative comment
# 338                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   received defective product speaker working flipkart denied return gave motorola service centre responding suggested pls pls buy electronic item flipkart
# 412                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             photo quality good camera app lag slow irritating battery average does not last long enough fast charging also mark phone tremendous heating issue get heated charging video recording video calling taking picture also running app display phone really amazing disappointed
# 417                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               battery drainage quickly and heating problem
# 446                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          phone good flipkart service worse
# 496                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          phone good flipkart service worse
# 538                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            first month mobile many lag app crashafter security update problem coming till camera superbfirt time use stock android basic apps need google brand applied salary file manager slightly panic
# 539                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     design camera user interface speaker display performance charging method con heating low battery backup lay camera app
# 588                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            first month mobile many lag app crashafter security update problem coming till camera superbfirt time use stock android basic apps need google brand applied salary file manager slightly panic
# 589                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     design camera user interface speaker display performance charging method con heating low battery backup lay camera app
# 656                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            first time us motorola smartphones go without hesitation every thing mark price segment ignore negative comment
# ...
# 9385                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      charging drain fast camera quality low heating issue
# 9393                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            product good delivery boy behaviour bad widely
# 9450                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  battery performance poor
# 9513                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         worst battery draining worth buy
#
#       Sentiment_Score Sentiment
# 26            -0.1987  Negative
# 31            -0.4019  Negative
# 72            -0.1987  Negative
# 77            -0.4019  Negative
# 332           -0.6582  Negative
# 338           -0.6369  Negative
# 412           -0.1987  Negative
# 417           -0.4019  Negative
# 446           -0.0516  Negative
# 496           -0.0516  Negative
# 538           -0.6915  Negative
# 539           -0.2732  Negative
# 588           -0.6915  Negative
# 589           -0.2732  Negative
# 656           -0.6582  Negative
# 662           -0.6369  Negative
# 710           -0.6369  Negative
# 772           -0.0516  Negative
# 852           -0.6582  Negative
# 902           -0.6582  Negative
# 908           -0.6369  Negative
# 970           -0.0516  Negative
# 1020          -0.0516  Negative
# 1082          -0.6915  Negative
# 1083          -0.2732  Negative
# 1127          -0.0772  Negative
# 1145          -0.5719  Negative
# 1227          -0.0772  Negative
# 1245          -0.5719  Negative
# 1327          -0.0772  Negative
# 1345          -0.5719  Negative
# 1427          -0.0772  Negative
# 1445          -0.5719  Negative
# 1478          -0.1531  Negative
# 1499          -0.2732  Negative
# 1528          -0.1531  Negative
# 1549          -0.2732  Negative
# 1578          -0.1531  Negative
# 1599          -0.2732  Negative
# 1723          -0.5423  Negative
# 1773          -0.5423  Negative
# 1882          -0.6597  Negative
# 1906          -0.2755  Negative
# 1982          -0.6597  Negative
# 2177          -0.1531  Negative
# 2198          -0.2732  Negative
# 2313          -0.2023  Negative
# 2328          -0.2516  Negative
# 2342          -0.2960  Negative
# 2348          -0.1779  Negative
# 2363          -0.2023  Negative
# 2378          -0.2516  Negative
# 2392          -0.2960  Negative
# 2398          -0.1779  Negative
# 2442          -0.3400  Negative
# 2492          -0.3400  Negative
# 2537          -0.0516  Negative
# 2586          -0.0516  Negative
# 2834          -0.2500  Negative
# 2879          -0.1847  Negative
# 2934          -0.2500  Negative
# 2984          -0.2500  Negative
# 3001          -0.1725  Negative
# 3012          -0.4767  Negative
# 3037          -0.2982  Negative
# 3038          -0.2023  Negative
# 3051          -0.1725  Negative
# 3062          -0.4767  Negative
# 3087          -0.2982  Negative
# 3088          -0.2023  Negative
# 3286          -0.2732  Negative
# 3336          -0.2732  Negative
# 3346          -0.1280  Negative
# 3441          -0.7351  Negative
# 3522          -0.5423  Negative
# 3596          -0.2263  Negative
# 3626          -0.0516  Negative
# 3643          -0.5423  Negative
# 3717          -0.2263  Negative
# 3747          -0.0516  Negative
# 3808          -0.3400  Negative
# 3848          -0.4019  Negative
# 3861          -0.7506  Negative
# 3862          -0.0516  Negative
# 3864          -0.5423  Negative
# 3869          -0.2263  Negative
# 3895          -0.5423  Negative
# 3939          -0.5423  Negative
# 4013          -0.2263  Negative
# 4043          -0.0516  Negative
# 4064          -0.7713  Negative
# 4070          -0.5423  Negative
# 4072          -0.7650  Negative
# 4087          -0.9100  Negative
# 4092          -0.6249  Negative
# 4143          -0.4404  Negative
# 4149          -0.7783  Negative
# 4151          -0.3624  Negative
# 4159          -0.4767  Negative
# 4296          -0.4019  Negative
# 4514          -0.3412  Negative
# 4522          -0.5423  Negative
# 4534          -0.4767  Negative
# 4547          -0.4019  Negative
# 4551          -0.5423  Negative
# 4559          -0.2500  Negative
# 4575          -0.6249  Negative
# 4576          -0.4767  Negative
# 4577          -0.6249  Negative
# 4578          -0.4019  Negative
# 4579          -0.5423  Negative
# 4580          -0.5667  Negative
# 4582          -0.5423  Negative
# 4583          -0.7650  Negative
# 4606          -0.3412  Negative
# 4614          -0.5423  Negative
# 4626          -0.4767  Negative
# 4639          -0.4019  Negative
# 4675          -0.4019  Negative
# 4711          -0.4019  Negative
# 4828          -0.3400  Negative
# 4834          -0.4019  Negative
# 4835          -0.3818  Negative
# 4847          -0.5267  Negative
# 4849          -0.8658  Negative
# 4870          -0.4404  Negative
# 4875          -0.3818  Negative
# 4911          -0.3818  Negative
# 4915          -0.5267  Negative
# 4924          -0.4767  Negative
# 4926          -0.4767  Negative
# 4928          -0.6249  Negative
# 4930          -0.7430  Negative
# 4948          -0.3400  Negative
# 4954          -0.4019  Negative
# 4955          -0.3818  Negative
# 4967          -0.5267  Negative
# 4969          -0.8658  Negative
# 4990          -0.4404  Negative
# 4995          -0.3818  Negative
# 5031          -0.3818  Negative
# 5035          -0.5267  Negative
# 5044          -0.4767  Negative
# 5046          -0.4767  Negative
# 5048          -0.6249  Negative
# 5050          -0.7430  Negative
# 5078          -0.4404  Negative
# 5083          -0.3818  Negative
# 5119          -0.3818  Negative
# 5123          -0.5267  Negative
# 5132          -0.4767  Negative
# 5134          -0.4767  Negative
# 5136          -0.6249  Negative
# 5138          -0.7430  Negative
# 5240          -0.1531  Negative
# 5322          -0.6486  Negative
# 5324          -0.2500  Negative
# 5346          -0.5423  Negative
# 5377          -0.6249  Negative
# 5379          -0.2247  Negative
# 5380          -0.2023  Negative
# 5383          -0.4019  Negative
# 5386          -0.6369  Negative
# 5407          -0.4588  Negative
# 5503          -0.1531  Negative
# 5585          -0.6486  Negative
# 5587          -0.2500  Negative
# 5608          -0.4588  Negative
# 5853          -0.3883  Negative
# 5857          -0.6249  Negative
# 5858          -0.9638  Negative
# 5861          -0.6249  Negative
# 5868          -0.8126  Negative
# 5872          -0.4767  Negative
# 5876          -0.6249  Negative
# 5956          -0.0588  Negative
# 6056          -0.0588  Negative
# 6095          -0.5423  Negative
# 6126          -0.6249  Negative
# 6128          -0.2247  Negative
# 6129          -0.2023  Negative
# 6132          -0.4019  Negative
# 6135          -0.6369  Negative
# 6190          -0.1601  Negative
# 6206          -0.4956  Negative
# 6218          -0.2411  Negative
# 6241          -0.3612  Negative
# 6244          -0.4019  Negative
# 6277          -0.5563  Negative
# 6289          -0.6214  Negative
# 6348          -0.1601  Negative
# 6364          -0.4956  Negative
# 6376          -0.2411  Negative
# 6399          -0.3612  Negative
# 6402          -0.4019  Negative
# 6435          -0.5563  Negative
# 6447          -0.6214  Negative
# 6506          -0.1601  Negative
# 6522          -0.4956  Negative
# 6534          -0.2411  Negative
# 6557          -0.3612  Negative
# 6560          -0.4019  Negative
# 6593          -0.5563  Negative
# 6605          -0.6214  Negative
# 6633          -0.0772  Negative
# 6715          -0.3818  Negative
# 6720          -0.7096  Negative
# 6727          -0.4588  Negative
# 6729          -0.8658  Negative
# 6731          -0.7351  Negative
# 6738          -0.4939  Negative
# 6739          -0.2500  Negative
# 6765          -0.0772  Negative
# 6847          -0.3818  Negative
# 6852          -0.7096  Negative
# 6859          -0.4588  Negative
# 6861          -0.8658  Negative
# 6863          -0.7351  Negative
# 6870          -0.4939  Negative
# 6871          -0.2500  Negative
# 6897          -0.0772  Negative
# 6979          -0.3818  Negative
# 6984          -0.7096  Negative
# 6991          -0.4588  Negative
# 6993          -0.8658  Negative
# 6995          -0.7351  Negative
# 7002          -0.4939  Negative
# 7003          -0.2500  Negative
# 7111          -0.1621  Negative
# 7135          -0.6705  Negative
# 7139          -0.5859  Negative
# 7154          -0.3818  Negative
# 7266          -0.1621  Negative
# 7290          -0.6705  Negative
# 7294          -0.5859  Negative
# 7309          -0.3818  Negative
# 7421          -0.1621  Negative
# 7445          -0.6705  Negative
# 7449          -0.5859  Negative
# 7464          -0.3818  Negative
# 7494          -0.0772  Negative
# 7576          -0.3818  Negative
# 7581          -0.7096  Negative
# 7588          -0.4588  Negative
# 7590          -0.8658  Negative
# 7592          -0.7351  Negative
# 7599          -0.4939  Negative
# 7600          -0.2500  Negative
# 7622          -0.4788  Negative
# 7626          -0.1531  Negative
# 7628          -0.4767  Negative
# 7649          -0.5423  Negative
# 7686          -0.4215  Negative
# 7695          -0.4767  Negative
# 7698          -0.5423  Negative
# 7701          -0.0516  Negative
# 7709          -0.8020  Negative
# 7717          -0.4767  Negative
# 7735          -0.4788  Negative
# 7739          -0.1531  Negative
# 7741          -0.4767  Negative
# 7762          -0.5423  Negative
# 7799          -0.4215  Negative
# 7808          -0.4767  Negative
# 7811          -0.5423  Negative
# 7814          -0.0516  Negative
# 7822          -0.8020  Negative
# 7830          -0.4767  Negative
# 7848          -0.4788  Negative
# 7852          -0.1531  Negative
# 7854          -0.4767  Negative
# 7875          -0.5423  Negative
# 7912          -0.4215  Negative
# 7921          -0.4767  Negative
# 7924          -0.5423  Negative
# 7927          -0.0516  Negative
# 7935          -0.8020  Negative
# 7943          -0.4767  Negative
# 7961          -0.4788  Negative
# 7965          -0.1531  Negative
# 7967          -0.4767  Negative
# 7988          -0.5423  Negative
# 8025          -0.4215  Negative
# 8034          -0.4767  Negative
# 8037          -0.5423  Negative
# 8040          -0.0516  Negative
# 8048          -0.8020  Negative
# 8056          -0.4767  Negative
# 8067          -0.5423  Negative
# 8087          -0.5423  Negative
# 8092          -0.3612  Negative
# 8093          -0.5423  Negative
# 8105          -0.5423  Negative
# 8110          -0.5423  Negative
# 8114          -0.5423  Negative
# 8120          -0.5423  Negative
# 8124          -0.4767  Negative
# 8126          -0.4019  Negative
# 8136          -0.2732  Negative
# 8146          -0.5423  Negative
# 8166          -0.5423  Negative
# 8171          -0.3612  Negative
# 8172          -0.5423  Negative
# 8184          -0.5423  Negative
# 8189          -0.5423  Negative
# 8193          -0.5423  Negative
# 8199          -0.5423  Negative
# 8203          -0.4767  Negative
# 8205          -0.4019  Negative
# 8215          -0.2732  Negative
# 8222          -0.5423  Negative
# 8286          -0.1174  Negative
# 8310          -0.2247  Negative
# 8460          -0.6249  Negative
# 8556          -0.6249  Negative
# 8672          -0.1174  Negative
# 8696          -0.2247  Negative
# 8734          -0.2960  Negative
# 8739          -0.4973  Negative
# 8758          -0.1531  Negative
# 8772          -0.5256  Negative
# 8782          -0.6369  Negative
# 8929          -0.2960  Negative
# 8934          -0.4973  Negative
# 8953          -0.1531  Negative
# 8967          -0.5256  Negative
# 8977          -0.6369  Negative
# 9029          -0.1531  Negative
# 9061          -0.5423  Negative
# 9106          -0.2732  Negative
# 9121          -0.4767  Negative
# 9125          -0.7351  Negative
# 9133          -0.4767  Negative
# 9134          -0.5423  Negative
# 9148          -0.6249  Negative
# 9151          -0.7906  Negative
# 9157          -0.5994  Negative
# 9173          -0.4019  Negative
# 9195          -0.2960  Negative
# 9218          -0.0516  Negative
# 9227          -0.6249  Negative
# 9228          -0.7351  Negative
# 9279          -0.4215  Negative
# 9286          -0.2732  Negative
# 9294          -0.1531  Negative
# 9378          -0.4215  Negative
# 9385          -0.2732  Negative
# 9393          -0.1531  Negative
# 9450          -0.4767  Negative
# 9513          -0.4939  Negative

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)

# %%
import pandas as pd

# Step 1: Load your DataFrame from the CSV file
input_file_path = r"C:\Users\Elakkiya\Downloads\flipkart\Flipkart_Products_reviews_with_sentiment.csv"
df = pd.read_csv(input_file_path)

# Step 2: Aggregate average sentiment scores by Product_Name
product_recommendations = df.groupby('Product_Name').agg({
    'Product_ID': 'first',           # Get the first Product_ID for each product
    'Sentiment': 'first',            # Get the first Sentiment for each product
    'Sentiment_Score': 'mean',       # Average sentiment score
    'Ratings': 'mean',               # Average rating
    'Reviews': 'count'               # Count of reviews
}).reset_index()

# Step 3: Sort the products by average sentiment score
product_recommendations = product_recommendations.sort_values(by='Sentiment_Score', ascending=False)

# Step 4: Save the resulting DataFrame to a CSV file
output_path = r"C:\Users\Elakkiya\Downloads\flipkart\Flipkart_mobile_recommendation.csv"
product_recommendations.to_csv(output_path, index=False)

print(f"Product recommendations saved to {output_path}")
# Out:
# Product recommendations saved to C:\Users\Elakkiya\Downloads\flipkart\Flipkart_mobile_recommendation.csv

# %%
df=pd.read_csv(r"C:\Users\Elakkiya\Downloads\flipkart\Flipkart_mobile_recommendation.csv")
df
# Out:
#                                                             Product_Name  \
# 0                                          Honor 7 (Mystery Grey, 16 GB)
# 1                                        Honor 7 (Fantasy Silver, 16 GB)
# 2                MOTOROLA Moto X (2nd Generation) (Black Leather, 16 GB)
# 3                                      Honor 10 (Midnight Black, 128 GB)
# 4                                        Honor 10 (Phantom Blue, 128 GB)
# 5                                        Honor 8 Pro (Navy Blue, 128 GB)
# 6                                   Honor 8 Pro (Midnight Black, 128 GB)
# 7                          Motorola Edge 20 5G (Frosted Emerald, 128 GB)
# 8                             Motorola Edge 20 5G (Frosted Onyx, 128 GB)
# 9                            Motorola Edge 20 5G (Frosted Pearl, 128 GB)
# 10                             MOTOROLA g82 5G (Meterorite Grey, 128 GB)
# 11                                  MOTOROLA g82 5G (White Lily, 128 GB)
# 12                         Motorola Edge 30 Pro (Stardust White, 128 GB)
# 13                            Motorola Edge 30 Pro (Cosmos Blue, 128 GB)
# 14                                                               Honor 8
# 15              MOTOROLA Motorola One Vision (Sapphire Gradient, 128 GB)
# 16                      Motorola Edge 30 Ultra (Starlight White, 128 GB)
# 17                   Motorola Edge 30 Ultra (Interstellar Black, 128 GB)
# 18                               MOTOROLA G71 5G (Neptune Green, 128 GB)
# 19                                Motorola edge 30 (Meteor Grey, 128 GB)
# 20                               Motorola edge 30 (Aurora Green, 128 GB)
# 21                                     Motorola g72 (Polar Blue, 128 GB)
# 22                                 Motorola g72 (Meteorite Grey, 128 GB)
# 23                                Motorola g73 5G (Lucent White, 128 GB)
# 24                               Motorola g73 5G (Midnight Blue, 128 GB)
# 25                                     Google Pixel 7 (Obsidian, 128 GB)
# 26                                   Google Pixel 7 (Lemongrass, 128 GB)
# 27                                         Google Pixel 7 (Snow, 128 GB)
# 28                                   MOTOROLA g82 5G(White Lily, 128 GB)
# 29                               Motorola Edge 30 (Aurora Green, 128 GB)
# 30                                Motorola Edge 30 (Meteor Grey, 128 GB)
# 31                  MOTOROLA Edge 50 Neo (PANTONE Nautical Blue, 256 GB)
# 32                      MOTOROLA Edge 50 Neo (PANTONE Poinciana, 256 GB)
# 33                      MOTOROLA Edge 50 Neo (PANTONE Grisaille, 256 GB)
# 34                          MOTOROLA Edge 50 Neo (PANTONE Latte, 256 GB)
# 35       Motorola Edge 50 Pro 5G with 68W Charger (Black Beauty, 256 GB)
# 36      Motorola Edge 50 Pro 5G with 68W Charger (Luxe Lavender, 256 GB)
# 37    Motorola Edge 50 Pro 5G with 68W Charger (Moonlight Pearl, 256 GB)
# 38                           MOTOROLA Moto G 5G (Frosted Silver, 128 GB)
# 39                            MOTOROLA Moto G 5G (Volcanic Grey, 128 GB)
# 40                              Motorola G60 (Frosted Champagne, 128 GB)
# 41                                    Motorola G60 (Soft Silver, 128 GB)
# 42                        Motorola Edge 20 Pro 5G (Midnight Sky, 128 GB)
# 43                    Motorola Edge 20 Pro 5G (Iridescent Cloud, 128 GB)
# 44                                     Honor 20 (Midnight Black, 128 GB)
# 45                                      Honor 20 (Sapphire Blue, 128 GB)
# 46                               Motorola Edge 40 (Viva Magenta, 256 GB)
# 47                                 Motorola Edge 40 (Lunar Blue, 256 GB)
# 48                              Motorola Edge 40 (Eclipse Black, 256 GB)
# 49                               Motorola Edge 40 (Nebula Green, 256 GB)
# 50                Motorola Edge 20 Fusion 5G (Electric Graphite, 128 GB)
# 51                       Motorola Edge 20 Fusion 5G (Cyber Teal, 128 GB)
# 52                                   OnePlus 7T (Frosted Silver, 128 GB)
# 53                                   OnePlus 7T (Frosted Silver, 256 GB)
# 54                                     OnePlus 7T (Glacier Blue, 128 GB)
# 55                                     OnePlus 7T (Glacier Blue, 256 GB)
# 56                               MOTOROLA Moto X4 (Sterling Blue, 64 GB)
# 57                   Motorola Edge 30 Ultra (Interstellar Black, 256 GB)
# 58                      Motorola Edge 30 Ultra (Starlight White, 256 GB)
# 59                               Motorola G62 5G (Midnight Gray, 128 GB)
# 60                                Motorola G62 5G (Frosted Blue, 128 GB)
# 61                           Motorola Edge 40 Neo (Black Beauty, 256 GB)
# 62                           Motorola Edge 40 Neo (Soothing Sea, 256 GB)
# 63                             Motorola Edge 40 Neo (Caneel Bay, 256 GB)
# 64                             Motorola Edge 40 Neo (Peach Fuzz, 256 GB)
# 65      Motorola Edge 50 Pro 5G with 125W Charger (Black Beauty, 256 GB)
# 66   Motorola Edge 50 Pro 5G with 125W Charger (Moonlight Pearl, 256 GB)
# 67     Motorola Edge 50 Pro 5G with 125W Charger (Luxe Lavender, 256 GB)
# 68        Motorola Edge 50 Pro 5G with 125W Charger (Caneel Bay, 256 GB)
# 69     Motorola Edge 50 Pro 5G with 125W Charger (Vanilla Cream, 256 GB)
# 70                                     OPPO Reno10 5G (Ice Blue, 256 GB)
# 71                                 OPPO Reno10 5G (Silvery Grey, 256 GB)
# 72                         Motorola Edge 50 Fusion (Forest Blue, 256 GB)
# 73                        Motorola Edge 50 Fusion (Forest Green, 256 GB)
# 74                            Motorola Edge 50 Fusion (Hot Pink, 256 GB)
# 75                    Motorola Edge 50 Fusion (Marshmallow Blue, 256 GB)
# 76                                 MOTOROLA Moto X4 (Super Black, 32 GB)
# 77                                OPPO Reno11 Pro 5G (Rock Grey, 256 GB)
# 78                        Motorola Edge 50 Fusion (Forest Green, 128 GB)
# 79                            Motorola Edge 50 Fusion (Hot Pink, 128 GB)
# 80                    Motorola Edge 50 Fusion (Marshmallow Blue, 128 GB)
# 81                         Motorola Edge 50 Fusion (Forest Blue, 128 GB)
# 82                           Motorola Edge 40 Neo (Black Beauty, 128 GB)
# 83                           Motorola Edge 40 Neo (Soothing Sea, 128 GB)
# 84                             Motorola Edge 40 Neo (Peach Fuzz, 128 GB)
# 85                             Motorola Edge 40 Neo (Caneel Bay, 128 GB)
# 86                            OPPO Reno10 Pro 5G (Glossy Purple, 256 GB)
# 87                             OPPO Reno10 Pro 5G (Silvery Grey, 256 GB)
# 88                                 OPPO Reno8 5G (Shimmer Black, 128 GB)
# 89                                  OPPO Reno8 5G (Shimmer Gold, 128 GB)
# 90                                    Google Pixel 7a (Charcoal, 128 GB)
# 91                                       Google Pixel 7a (Coral, 128 GB)
# 92                                        Google Pixel 7a (Snow, 128 GB)
# 93                                    Honor Play (Midnight Black, 64 GB)
# 94                                         Honor Play (Navy Blue, 64 GB)
# 95                                 OPPO Reno8T 5G (Sunrise Gold, 128 GB)
# 96                               OPPO Reno8T 5G (Midnight Black, 128 GB)
# 97                                 MOTOROLA Edge 50 (Peach Fuzz, 256 GB)
# 98                                 MOTOROLA Edge 50 (Koala Grey, 256 GB)
# 99                               MOTOROLA Edge 50 (Jungle Green, 256 GB)
# 100                                        Google Pixel 8 (Rose, 128 GB)
# 101                                    Google Pixel 8 (Obsidian, 128 GB)
# 102                                        Google Pixel 8 (Mint, 128 GB)
# 103                                       Google Pixel 8 (Hazel, 128 GB)
# 104                            OnePlus Nord CE4 (Celadon Marble, 128 GB)
# 105                            OnePlus Nord CE4 (Celadon Marble, 256 GB)
# 106                               OnePlus Nord CE4 (Dark Chrome, 128 GB)
# 107                                    OnePlus 8 (Glacial Green, 256 GB)
# 108                                OnePlus 8 (Interstellar Glow, 256 GB)
# 109                                       OnePlus 8 (Onyx Black, 256 GB)
# 110                             OnePlus Nord 3 5G (Tempest Gray, 128 GB)
# 111                                 OPPO F21 Pro (Sunset Orange, 128 GB)
# 112                                   OnePlus 8 Pro (Onyx Black, 256 GB)
# 113                                 Honor 90 5G (Midnight Black, 256 GB)
# 114                                 Honor 90 5G (Diamond Silver, 256 GB)
# 115                                   OPPO Reno11 5G (Rock Grey, 256 GB)
# 116                                  OPPO Reno11 5G (Wave Green, 128 GB)
# 117                                   OnePlus 7T Pro (Haze Blue, 256 GB)
# 118                                 Honor 90 5G (Diamond Silver, 512 GB)
# 119                                  Honor 90 5G (Emerald Green, 512 GB)
# 120                                 Honor 90 5G (Midnight Black, 512 GB)
# 121                                       OnePlus 8 (Onyx Black, 128 GB)
# 122                                    OnePlus 8 (Glacial Green, 128 GB)
# 123                                OnePlus 8 Pro (Glacial Green, 128 GB)
# 124                                   OnePlus 8 Pro (Onyx Black, 128 GB)
# 125                                   OPPO A78 5G (Glowing Blue, 128 GB)
# 126                                  OPPO F27 5G (Emerald Green, 128 GB)
# 127                                   OPPO F25 Pro 5G (Lava Red, 128 GB)
# 128                               OPPO F25 Pro 5G (Coral Purple, 128 GB)
# 129                                 OPPO F25 Pro 5G (Ocean Blue, 128 GB)
# 130                                 OPPO F25 Pro 5G (Ocean Blue, 256 GB)
# 131                                    OnePlus Nord (Blue Marble, 64 GB)
# 132                            OPPO F21s Pro 5G (Dawnlight Gold, 128 GB)
# 133                                   Honor X9b (Midnight Black, 256 GB)
# 134                                   Honor X9b (Sunrise Orange, 256 GB)
# 135                                OPPO F27 Pro+ (Midnight Navy, 256 GB)
# 136                                    OPPO F27 Pro+ (Dusk Pink, 128 GB)
# 137                                   OnePlus Nord (Blue Marble, 256 GB)
# 138                                          Honor 6 Plus (Black, 32 GB)
# 139                                   OnePlus Nord (Blue Marble, 128 GB)
# 140                               OnePlus Nord CE 5G (Blue Void, 256 GB)
#
#      Sentiment_Score   Ratings  Reviews
# 0           0.987240  4.600000       10
# 1           0.987240  4.600000       10
# 2           0.922600  4.380000       50
# 3           0.862016  4.800000      100
# 4           0.862016  4.800000      100
# 5           0.841794  4.750000      100
# 6           0.841794  4.750000      100
# 7           0.822806  4.680000       50
# 8           0.822806  4.680000       50
# 9           0.822806  4.680000       50
# 10          0.797124  4.510204       49
# 11          0.797124  4.510204       49
# 12          0.790578  4.560000       50
# 13          0.790578  4.560000       50
# 14          0.778718  4.705882       17
# 15          0.770054  4.560000       50
# 16          0.769474  4.720000       50
# 17          0.769474  4.720000       50
# 18          0.766382  4.540000       50
# 19          0.758710  4.620000       50
# 20          0.758710  4.620000       50
# 21          0.756676  4.540000       50
# 22          0.756676  4.540000       50
# 23          0.743522  4.408163       49
# 24          0.743522  4.408163       49
# 25          0.741370  4.535484      155
# 26          0.741370  4.535484      155
# 27          0.741370  4.535484      155
# 28          0.740560  4.580000       50
# 29          0.736270  4.640000       50
# 30          0.736270  4.640000       50
# 31          0.735131  4.816327       49
# 32          0.735131  4.816327       49
# 33          0.735131  4.816327       49
# 34          0.735131  4.816327       49
# 35          0.732690  4.620000       50
# 36          0.732690  4.620000       50
# 37          0.732690  4.620000       50
# 38          0.729784  4.620000       50
# 39          0.729784  4.620000       50
# 40          0.726448  4.680000       50
# 41          0.726448  4.680000       50
# 42          0.723684  4.620000       50
# 43          0.723684  4.620000       50
# 44          0.713882  4.924242       66
# 45          0.713882  4.924242       66
# 46          0.712524  4.600000       50
# 47          0.712524  4.600000       50
# 48          0.712524  4.600000       50
# 49          0.712524  4.600000       50
# 50          0.712076  4.530612       49
# 51          0.712076  4.530612       49
# 52          0.710694  4.887755       98
# 53          0.710694  4.887755       98
# 54          0.710694  4.887755       98
# 55          0.710694  4.887755       98
# 56          0.707308  4.680000       50
# 57          0.706738  4.620000       50
# 58          0.706738  4.620000       50
# 59          0.706278  4.541667       96
# 60          0.706278  4.541667       96
# 61          0.705402  4.720000       50
# 62          0.705402  4.720000       50
# 63          0.705402  4.720000       50
# 64          0.705402  4.720000       50
# 65          0.699434  4.600000       50
# 66          0.699434  4.600000       50
# 67          0.699434  4.600000       50
# 68          0.697146  4.600000       50
# 69          0.693757  4.433333       30
# 70          0.682023  4.642857       98
# 71          0.682023  4.642857       98
# 72          0.677626  4.720000       50
# 73          0.677626  4.720000       50
# 74          0.677626  4.720000       50
# 75          0.677626  4.720000       50
# 76          0.677508  4.576923       26
# 77          0.670883  4.694737       95
# 78          0.662396  4.666667       48
# 79          0.662396  4.666667       48
# 80          0.662396  4.666667       48
# 81          0.662396  4.666667       48
# 82          0.650588  4.680000       50
# 83          0.650588  4.680000       50
# 84          0.650588  4.680000       50
# 85          0.650588  4.680000       50
# 86          0.650006  4.541667       96
# 87          0.650006  4.541667       96
# 88          0.649824  4.737374       99
# 89          0.649824  4.737374       99
# 90          0.644629  4.354430      158
# 91          0.644629  4.354430      158
# 92          0.644629  4.354430      158
# 93          0.628127  4.703704      135
# 94          0.628127  4.703704      135
# 95          0.619552  4.552083       96
# 96          0.619552  4.552083       96
# 97          0.600826  4.391304       46
# 98          0.600826  4.391304       46
# 99          0.600826  4.391304       46
# 100         0.598072  4.227273      132
# 101         0.598072  4.227273      132
# 102         0.598072  4.227273      132
# 103         0.598072  4.227273      132
# 104         0.592521  4.644628      121
# 105         0.592521  4.644628      121
# 106         0.592521  4.644628      121
# 107         0.555108  4.611111       36
# 108         0.555108  4.611111       36
# 109         0.555108  4.611111       36
# 110         0.554617  4.502857      175
# 111         0.552187  4.587500       80
# 112         0.545733  4.666667        3
# 113         0.539519  4.016129       62
# 114         0.539519  4.016129       62
# 115         0.532173  4.463918       97
# 116         0.532173  4.463918       97
# 117         0.527058  4.500000       60
# 118         0.516110  4.306818       88
# 119         0.516110  4.306818       88
# 120         0.516110  4.306818       88
# 121         0.504707  4.545455       55
# 122         0.504707  4.545455       55
# 123         0.500325  4.250000        4
# 124         0.500325  4.250000        4
# 125         0.488130  4.297297       74
# 126         0.473585  4.076923       13
# 127         0.473381  4.230088      113
# 128         0.473381  4.230088      113
# 129         0.473381  4.230088      113
# 130         0.473381  4.230088      113
# 131         0.383829  4.285714        7
# 132         0.373528  4.026667       75
# 133         0.338334  3.593750       32
# 134         0.338334  3.593750       32
# 135         0.327380  3.822785       79
# 136         0.327380  3.822785       79
# 137         0.285342  3.578947       19
# 138         0.285177  3.166667       30
# 139         0.255761  3.555556       18
# 140         0.222530  3.108108       37
